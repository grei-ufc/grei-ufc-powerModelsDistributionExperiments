# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/Documents/mestrado/powerModelsExemplos`

# %% [markdown]
# # Leitura de modelo
# O **PowerModelsDistribution** ou PMD não possui suporte nativo para adicionar um custo na bateria, portanto o repositório foi modificado localmente para inclusão dessa variável no modelo a partir de pequenas modificações.
#
#
# Ao adicionar o custo do fonercimento de energia da bateria para o DSO é necessário também incluir a variável no problema de otimização.
#
#
# O problema de otimização nativo do PMD se da por:
# $$
# \min \sum_{t \in \mathcal{T}} \left(\sum_{g \in \mathcal{G}} c_g \cdot P_{g, t} \right)
# $$
#
# sendo $\mathcal{T}$ o conjunto de cada instante de tempo, $t$ o indice do instante de tempo, $\mathcal{G}$ o conjunto de geradores, considerando PV e fonte de tensão, $c_{g}$ o custo de geração de cada um dos geradores e $P_{g, t}$ a potência injetada por cada gerador em determinado instante de tempo. Como o custo é constante para cada gerador neste exemplo, não é necessário indicar o indice do tempo.
#
#
# A ideia do sistema em análise é criar um sistema que priorize o consumo local de energia. Para um teste inicial do favorecimento do consumo local de energia, pode-se considerar, que existe custo para injetar energia na rede, ou seja, um preço de venda negativo.
#
# $$
# \min \sum_{t \in \mathcal{T}} \left( \sum_{g \in \mathcal{G}} max({0, c_{s, g} \cdot P_{g, t})} + \sum_{b \in \mathcal{B}} max({0, c_{b} \cdot P_{b, t})} \right)
# $$
#
# onde $\mathcal{B}$ representa o conjunto dos sistemas de baterias, $c_{g}$ representa o custo de injeção de cada uma dos sistemas de baterias e $P_{b, t}$ a potencia injetada por cada sistema de baterias em determinado instante de tempo. A depender do custo de cada uma das fontes, a otimização será realizada dando prefência para as fontes mais baratas.

# %%
using PowerModelsDistribution
using Ipopt
using JuMP
using PowerPlots
using Plots

include("utils/load_data.jl")
results_path = "results/2025-04-21_solar_carga_armazenamento_opf_cost/"


########################
# construção de modelo #
########################

data_path = "1-MVLV-urban-5.303-1-no_sw"
load_data = get_load_data(data_path, 1, 1)

# coletando os dados de geração e mutiplicando para ser um valor próximo da carga
gen_data = get_gen_data(data_path, 1, 1) .* 20

eng_model = PowerModelsDistribution.parse_file("4Bus-DY-Bal/4Bus-DY-Bal.DSS")

solver = optimizer_with_attributes(
    Ipopt.Optimizer,
    "max_iter" => 20000,
    "tol" => 1e-10,)
# Out:
# [ PowerModelsDistribution | Info ] : Command 'calcvoltagebases' on line 36 in '4Bus-DY-Bal.DSS' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : Command 'solve' on line 37 in '4Bus-DY-Bal.DSS' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : basemva=100 is the default value, you may want to adjust sbase_default for better convergence
# MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.RawOptimizerAttribute("max_iter") => 20000, MathOptInterface.RawOptimizerAttribute("tol") => 1.0e-10])

# %% [markdown]
# ## Experimento com geração nominal de 750W para fonte fotovoltaica

# %%
#######################################
# adicionando série temporal de carga #
#######################################
# o passo da análise será de 15 minutos
# coletando 24horas de dados
time_indexes = Float64.(collect(1:96))


############################
# adicionando um novo bus #
############################
add_bus!(eng_model,
         "n5",
         rg=[0.0],
         grounded=[4],
         status=ENABLED,
         terminals=[1, 2, 3, 4],
         xg=[0.0])


##########################
# adicionando nova linha #
##########################
line3 = copy(eng_model["line"]["line2"])
line3["f_bus"] = "n3"
line3["t_bus"] = "n5"
eng_model["line"]["line3"] = line3


##########################
# adicionando nova carga #
##########################
add_load!(eng_model,
          "load2",
          "n5",
          [1, 2, 3, 4],
          pd_nom=[1800.0, 1800.0, 1800.0],
          configuration=WYE,
          status=ENABLED,
          vm_nom=2.40178,
          dispatchable=NO,
          qd_nom=[871.78, 871.78, 871.78])

# definindo a série temporal de carga ativa
# o parametro replace indica se a serie irá mutiplicar a potencia nominal ou substituir
# caso seja false, ela irá mutiplicar (caso a serie temporal esteja em PU)
pd_ts_l1 = Dict("time" => time_indexes,
                "values" => load_data.pload,
                "offset" => 0,
                "replace" => false)

# definindo a série temporal de carga reativa
qd_ts_l1 = Dict("time" => time_indexes,
                "values" => load_data.qload,
                "offset" => 0,
                "replace" => false)

# indicando a série temporal designada para carga load1
eng_model["time_series"] = Dict("pd_ts_l1" => pd_ts_l1, "qd_ts_l1" => qd_ts_l1)
eng_model["load"]["load1"]["time_series"] = Dict("pd_nom" => "pd_ts_l1",
                                                 "qd_nom" => "qd_ts_l1")

eng_model["time_series"] = Dict("pd_ts_l1" => pd_ts_l1, "qd_ts_l1" => qd_ts_l1)
eng_model["load"]["load2"]["time_series"] = Dict("pd_nom" => "pd_ts_l1",
                                                 "qd_nom" => "qd_ts_l1")


#########################################
# adicionando série temporal de geracao #
#########################################
# definindo que a série temporal é a mesma para cada uma das fases
gen_data_1 = []
for i in gen_data.pgen
    push!(gen_data_1, [i, i, i, 0])
end

# definindo a série temporal de geração
pd_ts_g1 = Dict("time" => time_indexes,
                "values" => gen_data_1,
                "offset" => 0,
                "replace" => false)

# adicionando um sistema fotovoltaico
add_solar!(eng_model,
           "pv1",
           "n4",
           configuration=WYE,
           [1, 2, 3, 4],
           pg=[250, 250, 250, 0],
           qg=[0, 0, 0, 0],
           pg_ub=[250, 250, 250, 0], # potencia ativa nominal
           pg_lb=[0, 0, 0, 0], # limite inferior de potencia ativa
           qg_ub=[0, 0, 0, 0], # potencia reativa nominal
           qg_lb=[0, 0, 0, 0]) # limite inferior de potencia reativa
eng_model["time_series"]["pd_ts_g1"] = pd_ts_g1
eng_model["solar"]["pv1"]["time_series"] = Dict("pg_ub" => "pd_ts_g1",
                                                "pg_lb" => "pd_ts_g1")

add_solar!(eng_model,
           "pv2",
           "n5",
           configuration=WYE,
           [1, 2, 3, 4],
           pg=[250, 250, 250, 0],
           qg=[0, 0, 0, 0],
           pg_ub=[250, 250, 250, 0], # potencia ativa nominal
           pg_lb=[0, 0, 0, 0], # limite inferior de potencia ativa
           qg_ub=[0, 0, 0, 0], # potencia reativa nominal
           qg_lb=[0, 0, 0, 0]) # limite inferior de potencia reativa
eng_model["time_series"]["pd_ts_g1"] = pd_ts_g1
eng_model["solar"]["pv2"]["time_series"] = Dict("pg_ub" => "pd_ts_g1",
                                                "pg_lb" => "pd_ts_g1")


#############################
# adicionando armazenamento #
#############################
add_storage!(eng_model,
             "bess_1",
             "n4",
             configuration=WYE,
             [1, 2, 3, 4],
             energy=40000,
             energy_ub=80000,
             charge_ub=7000,
             discharge_ub=7000,
             sm_ub=150000,
             cm_ub=1e6,
             qex=0,
             pex=0,
             charge_efficiency=100,
             discharge_efficiency=100,
             qs_ub=0,
             qs_lb=0,
             rs=0,
             xs=0)

add_storage!(eng_model,
             "bess_2",
             "n5",
             configuration=WYE,
             [1, 2, 3, 4],
             energy=40000,
             energy_ub=80000,
             charge_ub=7000,
             discharge_ub=7000,
             sm_ub=150000,
             cm_ub=1e6,
             qex=0,
             pex=0,
             charge_efficiency=100,
             discharge_efficiency=100,
             qs_ub=0,
             qs_lb=0,
             rs=0,
             xs=0)

eng_model["settings"]["sbase_default"] = 1000

# venda / compra
eng_model["voltage_source"]["source"]["cost_pg_parameters"] = [-100, 100]

eng_model["solar"]["pv1"]["cost_pg_parameters"] = [50, 50]
eng_model["solar"]["pv2"]["cost_pg_parameters"] = [50, 50]

eng_model["storage"]["bess_1"]["cost"] = [30, 50]
eng_model["storage"]["bess_2"]["cost"] = [30, 50]
# Out:
# 2-element Vector{Int64}:
#  30
#  50

# %%
eng_model = make_multinetwork(eng_model) # indicando que se trata de uma série temporal
set_time_elapsed!(eng_model, 0.25) # indicando que o passo é de 15 minutos 
result = solve_mc_model(eng_model, ACPUPowerModel, solver, build_mc_mn_opf_cost; multinetwork=true)
# Out:
# [ PowerModelsDistribution | Info ] : assuming time is in hours for time_elapsed inference. if this is incorrect, manually adjust with set_time_elapsed!
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:   117184
# Number of nonzeros in inequality constraint Jacobian.:    14400
# Number of nonzeros in Lagrangian Hessian.............:   272388
#
# Total number of variables............................:    18306
#                      variables with only lower bounds:     2592
#                 variables with lower and upper bounds:     4194
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    17184
# Total number of inequality constraints...............:     5952
#         inequality constraints with only lower bounds:     2016
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:     3936
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -1.8971955e+03 5.24e+00 5.00e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -1.8898061e+03 5.22e+00 1.00e+02  -1.0 5.75e+00   2.0 1.94e-01 2.91e-03h  1
#    2 -1.7820413e+03 5.02e+00 6.89e+02  -1.0 5.73e+00   2.4 4.47e-01 3.86e-02h  1
#    3 -1.6184318e+03 4.67e+00 5.54e+02  -1.0 5.51e+00   1.9 6.88e-01 6.87e-02h  1
#    4 -1.3322455e+03 4.36e+00 1.39e+03  -1.0 5.14e+00   2.4 8.51e-01 6.78e-02h  1
#    5 -6.2427927e+02 3.71e+00 9.09e+02  -1.0 4.79e+00   1.9 4.78e-01 1.48e-01h  1
#    6 -3.4732059e+02 3.45e+00 6.10e+02  -1.0 4.11e+00   1.4 3.73e-01 7.07e-02h  1
#    7  2.6787575e+02 2.88e+00 4.60e+02  -1.0 5.27e+00   0.9 2.78e-01 1.66e-01h  1
#    8  4.1889692e+02 2.79e+00 4.45e+02  -1.0 3.25e+00   1.4 3.48e-02 3.25e-02h  1
#    9  6.4165083e+02 2.66e+00 4.24e+02  -1.0 3.10e+00   1.8 5.34e-02 4.47e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.0001115e+03 2.48e+00 1.16e+03  -1.0 2.96e+00   2.2 1.31e-01 6.82e-02h  1
#   11  1.3736359e+03 2.27e+00 5.23e+03  -1.0 2.75e+00   1.7 1.53e-01 8.42e-02h  1
#   12  1.7376496e+03 2.09e+00 2.63e+04  -1.0 2.52e+00   2.2 1.92e-01 7.96e-02h  1
#   13  2.0597314e+03 1.90e+00 8.21e+04  -1.0 2.38e+00   1.7 2.56e-01 8.95e-02h  1
#   14  2.2360733e+03 1.72e+00 1.49e+05  -1.0 3.53e+00   1.2 2.25e-01 9.67e-02h  1
#   15  2.5603320e+03 1.52e+00 3.20e+05  -1.0 2.15e+00   1.6 3.44e-01 1.16e-01h  1
#   16  2.6653336e+03 1.35e+00 6.19e+05  -1.0 3.31e+00   1.2 3.70e-01 1.14e-01h  1
#   17  3.0065632e+03 1.11e+00 1.15e+06  -1.0 1.91e+00   1.6 5.85e-01 1.77e-01h  1
#   18  2.9979684e+03 9.45e-01 1.16e+06  -1.0 3.07e+00   1.1 2.42e-01 1.48e-01f  1
#   19  3.2220271e+03 7.30e-01 1.76e+06  -1.0 1.67e+00   1.5 6.20e-01 2.28e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  3.5010719e+03 5.60e-01 3.07e+06  -1.0 8.62e-01   2.0 1.00e+00 2.33e-01h  1
#   21  3.5195671e+03 4.63e-01 3.74e+06  -1.0 1.43e+00   1.5 6.77e-01 1.73e-01h  1
#   22  3.7017698e+03 3.17e-01 3.00e+06  -1.0 7.00e-01   1.9 6.32e-01 3.15e-01h  1
#   23  3.5860281e+03 2.00e-01 2.59e+06  -1.0 1.26e+00   1.4 9.37e-01 3.71e-01f  1
#   24  3.5591230e+03 1.17e-01 2.95e+06  -1.0 4.87e-01   1.9 1.00e+00 4.13e-01f  1
#   25  3.3045499e+03 7.74e-02 2.55e+06  -1.0 1.19e+00   1.4 6.08e-01 3.39e-01f  1
#   26  3.1611880e+03 4.23e-02 2.08e+06  -1.0 4.27e-01   1.8 1.00e+00 4.53e-01f  1
#   27  2.8409600e+03 2.74e-02 1.47e+06  -1.0 1.21e+00   1.3 6.05e-01 3.52e-01f  1
#   28  2.6245903e+03 1.16e-02 1.44e+06  -1.0 4.06e-01   1.8 1.00e+00 5.78e-01f  1
#   29  2.2253092e+03 4.76e-03 2.02e+06  -1.0 1.24e+00   1.3 7.21e-01 5.89e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.8418415e+03 1.90e-03 1.59e+07  -1.0 4.18e-01   1.7 1.00e+00 6.01e-01f  1
#   31  1.5146547e+03 1.23e-03 3.71e+06  -1.0 1.07e+00   1.2 5.39e-01 3.52e-01f  1
#   32  1.3098739e+03 7.14e-04 5.85e+06  -1.0 4.64e-01   1.7 1.00e+00 4.21e-01f  1
#   33  1.0354725e+03 4.47e-04 2.47e+06  -1.0 1.19e+00   1.2 6.23e-01 3.74e-01f  1
#   34  7.1134520e+02 2.21e-04 1.89e+06  -1.0 4.60e-01   1.6 1.00e+00 5.07e-01f  1
#   35  4.2615359e+02 3.88e-04 1.82e+06  -1.0 1.30e+00   1.1 1.00e+00 5.53e-01f  1
#   36 -1.0117537e+02 2.15e-04 1.58e+06  -1.0 5.02e-01   1.6 1.00e+00 5.74e-01f  1
#   37 -2.4184481e+02 7.69e-05 8.83e+05  -1.0 1.95e-01   2.0 1.00e+00 7.60e-01f  1
#   38 -3.7786992e+02 1.20e-04 2.50e+06  -1.0 5.98e-01   1.5 8.88e-01 4.72e-01f  1
#   39 -5.8060773e+02 6.15e-05 1.21e+07  -1.0 2.01e-01   1.9 1.00e+00 5.87e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40 -5.0665116e+02 8.73e-05 1.12e+07  -1.0 5.77e-01   1.5 6.67e-01 7.54e-01H  1
#   41 -7.1517657e+02 5.97e-05 7.81e+06  -1.0 2.06e-01   1.9 4.18e-01 2.81e-01f  1
#   42 -1.0071697e+03 1.82e-04 3.47e+07  -1.0 5.92e-01   1.4 6.53e-01 5.57e-01f  1
#   43 -1.2372403e+03 1.11e-04 4.19e+08  -1.0 2.79e-01   1.8 9.08e-02 7.93e-01f  1
#   44 -1.2403256e+03 6.20e-05 2.32e+08  -1.0 1.37e-02   4.1 9.98e-02 4.39e-01h  1
#   45 -1.2406032e+03 9.13e-10 8.81e+06  -1.0 3.48e-03   7.2 1.00e+00 1.00e+00h  1
#   46 -1.2406000e+03 1.98e-10 1.62e+08  -1.0 2.51e-04   6.7 2.45e-01 7.83e-01h  1
#   47 -1.2405957e+03 1.73e-10 1.78e+08  -1.0 8.90e-04   7.1 1.93e-02 1.25e-01f  4
#   48 -1.2405905e+03 3.12e-11 1.43e+08  -1.0 1.53e-04   7.6 1.00e+00 1.00e+00h  1
#   49 -1.2405987e+03 2.29e-11 7.23e+08  -1.0 1.52e-04   7.1 1.89e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -1.2405920e+03 2.68e-11 3.20e+09  -1.0 2.98e-04   8.4 1.40e-01 1.00e+00f  1
#   51 -1.2405900e+03 3.02e-11 8.93e+08  -1.0 1.07e-04   8.8 1.00e+00 1.00e+00h  1
#   52 -1.2405904e+03 2.93e-11 1.87e+07  -1.0 1.17e-05   8.4 1.00e+00 1.00e+00f  1
#   53 -1.2405926e+03 2.59e-11 9.06e+05  -1.0 1.11e-05   7.9 1.00e+00 1.00e+00f  1
#   54 -1.2406001e+03 2.20e-11 6.08e+05  -1.7 3.60e-06   7.4 1.00e+00 1.00e+00f  1
#   55 -1.2406223e+03 2.77e-11 6.18e+04  -1.7 1.36e-05   6.9 1.00e+00 1.00e+00f  1
#   56 -1.2406892e+03 2.55e-11 7.04e+04  -2.5 1.04e-05   6.5 1.00e+00 1.00e+00f  1
#   57 -1.2408905e+03 3.10e-11 5.49e+03  -2.5 3.16e-05   6.0 1.00e+00 1.00e+00f  1
#   58 -1.2414907e+03 3.19e-11 2.41e+04  -2.5 9.18e-05   5.5 1.00e+00 1.00e+00f  1
#   59 -1.2432550e+03 1.29e-10 1.11e+05  -2.5 2.61e-04   5.0 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -1.2468930e+03 6.22e-10 2.82e+05  -2.5 7.17e-04   4.6 1.00e+00 7.04e-01f  1
#   61 -1.2587339e+03 6.35e-09 5.88e+06  -2.5 1.98e-03   4.1 1.00e+00 7.90e-01f  1
#   62 -1.2647563e+03 7.58e-09 4.84e+06  -2.5 5.44e-03   3.6 1.00e+00 1.80e-01f  1
#   63 -1.2741320e+03 2.10e-08 3.75e+06  -2.5 3.09e-02   3.1 6.52e-01 1.71e-01f  1
#   64 -1.2894758e+03 9.89e-08 2.78e+06  -2.5 4.02e-02   2.6 6.23e-01 1.18e-01f  1
#   65 -1.4151101e+03 4.61e-05 2.70e+09  -2.5 1.01e-01   2.2 3.04e-01 1.00e+00f  1
#   66 -1.2977095e+03 2.40e-05 4.75e+09  -2.5 2.78e-01   1.7 4.96e-01 9.31e-01H  1
#   67 -1.5476021e+03 4.67e-04 1.06e+11  -2.5 8.14e-01   1.2 1.77e-01 6.84e-01f  1
#   68 -1.9727678e+03 2.81e-04 4.64e+11  -2.5 2.46e-01   1.6 4.11e-03 1.00e+00f  1
#   69 -2.2105032e+03 7.07e-05 8.28e+10  -2.5 1.38e-01   2.1 9.98e-01 7.73e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70 -2.1821542e+03 8.00e-06 6.38e+09  -2.5 4.36e-01   1.6 3.97e-01 1.00e+00H  1
#   71 -2.4898123e+03 8.31e-05 3.79e+10  -2.5 1.41e-01   2.0 1.00e+00 1.00e+00f  1
#   72 -2.7205933e+03 6.90e-05 3.02e+09  -2.5 3.22e-01   1.5 1.63e-01 2.76e-01f  1
#   73 -2.8105904e+03 5.31e-05 2.25e+09  -2.5 1.77e-01   2.0 4.44e-01 2.35e-01f  1
#   74 -2.3691834e+03 1.61e-05 3.73e+09  -2.5 5.73e-01   1.5 3.04e-01 1.00e+00H  1
#   75 -2.9909927e+03 8.97e-05 2.83e+11  -2.5 2.64e-01   1.9 5.12e-01 1.00e+00f  1
#   76 -3.2163585e+03 8.36e-05 1.95e+11  -2.5 5.08e-01   1.4 4.77e-01 1.96e-01f  1
#   77 -3.0379746e+03 1.86e-06 2.19e+11  -2.5 2.12e-01   1.9 6.41e-02 1.00e+00H  1
#   78 -3.2555675e+03 1.34e-04 9.25e+11  -2.5 6.38e-01   1.4 1.15e-01 4.55e-01f  2
#   79 -3.4819564e+03 8.21e-05 4.61e+09  -2.5 2.61e-01   1.8 1.00e+00 4.01e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80 -3.4824683e+03 8.21e-05 4.60e+09  -2.5 5.02e-01   1.3 3.28e-02 2.03e-04F  1
#   81 -3.4848650e+03 8.19e-05 4.60e+09  -2.5 2.19e-01   1.8 8.95e-01 1.96e-03F  1
#   82 -3.5969839e+03 8.32e-05 2.96e+09  -2.5 5.52e-01   1.3 2.37e-01 1.57e-01f  2
#   83 -3.6142429e+03 8.16e-05 2.91e+09  -2.5 3.03e-01   1.7 2.09e-01 1.73e-02F  1
#   84 -3.6207105e+03 8.97e-05 2.14e+09  -2.5 8.11e-01   1.2 2.10e-01 2.04e-01f  2
#   85 -3.1469807e+03 7.05e-06 3.01e+09  -2.5 3.26e-01   1.7 1.31e-01 1.00e+00H  1
#   86 -3.1469807e+03 6.51e-06 2.47e+10  -2.5 1.01e-04  15.5 1.00e+00 7.68e-02h  1
#   87 -3.1469807e+03 6.44e-06 2.54e+10  -2.5 9.34e-05  15.0 1.00e+00 9.74e-03h  1
#   88 -3.1469815e+03 2.54e-11 3.27e+10  -2.5 9.25e-05  14.5 1.00e+00 1.00e+00f  1
#   89 -3.1469815e+03 1.74e-11 3.56e+05  -2.5 5.16e-11  14.1 9.97e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90 -3.1469815e+03 2.37e-11 3.38e+04  -3.8 5.89e-10  13.6 1.00e+00 1.00e+00f  1
#   91 -3.1469815e+03 2.22e-11 3.50e+04  -3.8 2.68e-09  13.1 1.00e+00 1.00e+00f  1
#   92 -3.1469815e+03 1.94e-11 7.41e+03  -3.8 1.70e-09  12.6 1.00e+00 1.00e+00f  1
#   93 -3.1469815e+03 1.91e-11 2.87e+04  -3.8 5.72e-09  12.2 1.00e+00 1.00e+00f  1
#   94 -3.1469815e+03 1.88e-11 7.35e+05  -3.8 6.21e-09  11.7 1.00e+00 1.00e+00f  1
#   95 -3.1469815e+03 2.49e-11 4.87e+06  -3.8 1.46e-08  11.2 1.00e+00 1.00e+00f  1
#   96 -3.1469815e+03 3.62e-11 9.14e+06  -3.8 2.06e-08  10.7 1.00e+00 1.00e+00f  1
#   97 -3.1469815e+03 2.87e-11 1.73e+07  -3.8 4.06e-08  10.3 1.00e+00 1.00e+00f  1
#   98 -3.1469815e+03 2.65e-11 2.39e+07  -3.8 6.43e-08   9.8 1.00e+00 1.00e+00f  1
#   99 -3.1469816e+03 2.79e-11 3.41e+07  -3.8 1.17e-07   9.3 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100 -3.1469818e+03 2.50e-11 4.31e+07  -3.8 1.92e-07   8.8 1.00e+00 1.00e+00f  1
#  101 -3.1469825e+03 2.83e-11 5.44e+07  -3.8 3.33e-07   8.3 1.00e+00 1.00e+00f  1
#  102 -3.1469845e+03 2.45e-11 6.34e+07  -3.8 5.45e-07   7.9 1.00e+00 1.00e+00f  1
#  103 -3.1469904e+03 3.19e-11 6.97e+07  -3.8 1.13e-06   7.4 1.00e+00 1.00e+00f  1
#  104 -3.1470082e+03 2.47e-11 6.69e+07  -3.8 3.39e-06   6.9 1.00e+00 1.00e+00f  1
#  105 -3.1470614e+03 2.74e-11 5.20e+07  -3.8 1.01e-05   6.4 1.00e+00 1.00e+00f  1
#  106 -3.1472193e+03 2.72e-11 2.85e+07  -3.8 2.96e-05   6.0 1.00e+00 1.00e+00f  1
#  107 -3.1474726e+03 2.86e-11 8.22e+06  -3.8 7.95e-05   5.5 1.00e+00 5.72e-01f  1
#  108 -3.1479946e+03 2.76e-11 5.15e+06  -3.8 2.26e-04   5.0 5.52e-01 4.42e-01f  1
#  109 -3.1491020e+03 1.13e-10 1.53e+08  -3.8 5.22e-04   4.5 1.00e+00 3.45e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110 -3.1535813e+03 1.90e-09 7.81e+07  -3.8 1.42e-03   4.1 4.00e-01 4.82e-01f  1
#  111 -3.1813063e+03 6.96e-08 5.50e+09  -3.8 4.15e-03   3.6 1.00e+00 1.00e+00f  1
#  112 -3.2587200e+03 6.22e-07 4.27e+10  -3.8 1.24e-02   3.1 3.11e-01 1.00e+00f  1
#  113 -3.3061756e+03 6.22e-07 1.12e+07  -3.8 4.18e-02   2.6 1.00e+00 2.39e-01f  1
#  114 -3.6411499e+03 4.81e-05 5.48e+14  -3.8 1.01e-01   2.1 2.54e-03 1.00e+00f  1
#  115 -3.9222101e+03 1.43e-04 3.38e+14  -3.8 3.34e-01   1.7 9.58e-01 4.29e-01f  1
#  116 -4.0023976e+03 1.14e-04 2.66e+14  -3.8 9.62e-01   1.2 5.49e-02 2.28e-01f  2
#  117 -4.1200522e+03 8.73e-05 1.96e+14  -3.8 3.34e-01   1.6 6.08e-01 2.81e-01f  1
#  118 -3.9927446e+03 1.12e-04 4.90e+13  -3.8 1.29e-01   2.0 3.89e-04 1.00e+00h  1
#  119 -4.2347293e+03 9.31e-05 4.07e+13  -3.8 4.05e-01   1.6 2.64e-01 1.76e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120 -4.1516818e+03 1.80e-04 1.57e+13  -3.8 2.18e-01   2.0 1.00e+00 7.58e-01h  1
#  121 -4.3391143e+03 1.49e-04 1.26e+13  -3.8 3.29e-01   1.5 7.06e-04 2.07e-01f  3
#  122 -4.3368056e+03 7.77e-05 6.95e+12  -3.8 1.42e-01   1.9 1.00e+00 5.14e-01h  1
#  123 -4.3962593e+03 7.02e-05 5.53e+12  -3.8 4.30e-01   1.5 3.90e-03 2.16e-01f  2
#  124 -4.0974816e+03 1.63e-05 1.69e+12  -3.8 1.82e-01   1.9 4.04e-01 8.94e-01H  1
#  125 -4.4993200e+03 1.70e-04 1.16e+12  -3.8 5.14e-01   1.4 2.72e-01 3.31e-01f  1
#  126 -4.5439235e+03 8.56e-05 5.97e+11  -3.8 3.08e-01   1.8 2.14e-03 5.37e-01f  1
#  127 -4.6768060e+03 7.92e-05 2.07e+12  -3.8 5.56e-01   1.4 1.56e-01 1.33e-01f  1
#  128 -4.6774296e+03 7.92e-05 2.07e+12  -3.8 2.00e-01   1.8 8.44e-01 5.48e-04f  1
#  129 -4.7478365e+03 7.35e-05 1.80e+12  -3.8 5.41e-01   1.3 5.42e-01 7.95e-02f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130 -4.1367720e+03 3.77e-06 4.03e+11  -3.8 2.64e-01   1.7 7.56e-01 1.00e+00H  1
#  131 -4.7046354e+03 6.64e-05 1.92e+12  -3.8 8.05e-01   1.3 1.16e-01 2.46e-01f  3
#  132 -4.7366091e+03 6.55e-05 1.89e+12  -3.8 3.42e-01   1.7 2.03e-01 1.84e-02f  1
#  133 -4.7367226e+03 6.54e-05 1.89e+12  -3.8 7.74e-01   1.2 1.60e-01 2.92e-05F  1
#  134 -4.8599172e+03 1.08e-04 1.24e+12  -3.8 3.85e-01   1.6 7.99e-02 2.48e-01f  2
#  135 -4.8599928e+03 1.08e-04 1.24e+12  -3.8 1.36e+00   2.1 1.92e-01 9.35e-05f  1
#  136 -4.8606776e+03 1.08e-04 1.24e+12  -3.8 4.06e-01   1.6 1.90e-04 3.48e-04f  1
#  137 -4.8606779e+03 1.08e-04 1.24e+12  -3.8 5.54e-03   9.4 1.93e-02 6.78e-04h  1
#  138 -4.9408357e+03 1.00e-04 1.15e+12  -3.8 1.03e+00    -  7.98e-01 6.87e-02f  1
#  139 -4.9408365e+03 9.99e-05 1.15e+12  -3.8 5.16e-03  11.7 6.97e-06 2.75e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140 -4.9408369e+03 9.98e-05 1.15e+12  -3.8 5.14e-03  11.2 1.13e-03 1.17e-03h  1
#  141 -4.9408376e+03 9.95e-05 1.15e+12  -3.8 5.14e-03  10.7 1.13e-02 2.48e-03h  1
#  142 -4.9412260e+03 6.87e-05 7.91e+11  -3.8 5.14e-03    -  1.17e-02 3.10e-01h  1
#  143 -4.9412261e+03 6.87e-05 7.91e+11  -3.8 3.54e-03  10.2 1.19e-04 5.79e-04h  1
#  144 -4.9412264e+03 6.86e-05 7.90e+11  -3.8 3.54e-03   9.7 6.59e-03 1.37e-03h  1
#  145 -4.9412268e+03 6.84e-05 7.88e+11  -3.8 3.53e-03   9.3 5.50e-03 2.27e-03h  1
#  146 -4.9412277e+03 6.80e-05 7.83e+11  -3.8 3.53e-03   8.8 4.77e-02 5.90e-03h  1
#  147 -4.9412297e+03 6.68e-05 7.70e+11  -3.8 3.51e-03   8.3 2.59e-02 1.73e-02h  1
#  148 -4.9412312e+03 6.54e-05 7.53e+11  -3.8 3.45e-03   7.8 5.68e-01 2.15e-02h  1
#  149 -4.9412301e+03 5.93e-05 6.83e+11  -3.8 3.37e-03   7.4 1.60e-01 9.37e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150 -4.9417667e+03 4.40e-05 2.24e+12  -3.8 3.04e-03    -  4.14e-01 2.58e-01f  1
#  151 -4.9417665e+03 4.30e-05 2.19e+12  -3.8 2.27e-03   6.9 1.00e+00 2.30e-02h  1
#  152 -4.9417728e+03 1.50e-05 1.73e+11  -3.8 2.21e-03   6.4 5.66e-01 6.50e-01f  1
#  153 -4.9492568e+03 8.57e-09 1.08e+13  -3.8 7.38e-03    -  1.03e-01 1.00e+00f  1
#  154 -4.9493452e+03 2.71e-09 3.40e+12  -3.8 3.54e-05   5.9 1.00e+00 6.84e-01f  1
#  155 -4.9497207e+03 9.96e-11 5.54e+10  -3.8 1.56e-04   5.5 1.00e+00 1.00e+00f  1
#  156 -4.9504530e+03 3.72e-10 2.17e+10  -3.8 4.68e-04   5.0 1.00e+00 6.28e-01f  1
#  157 -4.9537782e+03 8.21e-09 3.20e+09  -3.8 1.46e-03   4.5 1.00e+00 1.00e+00f  1
#  158 -4.9579044e+03 1.73e-08 2.01e+09  -3.8 4.39e-03   4.0 1.00e+00 4.11e-01f  1
#  159 -4.9819011e+03 1.16e-07 9.58e+08  -3.8 5.15e-03   3.5 1.00e+00 9.30e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160 -5.0460761e+03 9.60e-07 1.22e+09  -3.8 1.38e-02   3.1 1.00e+00 1.00e+00f  1
#  161 -5.0792671e+03 8.77e-06 6.40e+08  -3.8 4.44e-02   2.6 1.00e+00 8.64e-01f  1
#  162 -5.0854100e+03 1.86e-05 6.35e+08  -3.8 1.40e-01   2.1 5.96e-01 4.96e-01f  1
#  163 -5.1365100e+03 1.63e-05 3.22e+08  -3.8 3.67e-01   1.6 1.72e-03 1.32e-01f  3
#  164 -5.1781182e+03 1.53e-05 5.88e+05  -5.7 8.52e-01   1.2 1.43e-01 6.46e-02f  1
#  165 -5.1781183e+03 1.53e-05 5.89e+05  -5.7 3.56e-01   1.6 7.39e-02 4.11e-08F  1
#  166 -4.8772905e+03 1.82e-05 6.93e+05  -5.7 1.48e-01   2.0 4.38e-01 8.36e-01H  1
#  167 -5.1922177e+03 5.29e-05 6.87e+05  -5.7 4.31e-01   1.5 2.08e-01 2.54e-01f  2
#  168 -5.2637887e+03 4.44e-05 4.32e+05  -5.7 1.81e-01   2.0 5.19e-01 2.45e-01f  2
#  169 -5.3001754e+03 4.21e-05 3.76e+05  -5.7 4.17e-01   1.5 6.80e-01 8.28e-02f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170 -4.7851536e+03 1.04e-05 5.58e+05  -5.7 1.59e-01   1.9 4.70e-01 9.49e-01H  1
#  171 -4.8665575e+03 1.03e-05 5.38e+05  -5.7 4.75e-01   1.4 5.43e-02 2.70e-02f  1
#  172 -5.0513813e+03 1.15e-05 8.37e+07  -5.7 2.11e-01   1.9 1.23e-03 2.05e-01f  2
#  173 -5.2641538e+03 4.56e-05 7.10e+07  -5.7 5.23e-01   1.4 1.77e-01 1.59e-01f  2
#  174 -5.3132051e+03 4.36e-05 4.73e+07  -5.7 1.90e-01   1.8 9.06e-01 3.66e-01f  1
#  175 -5.4467389e+03 4.25e-05 2.43e+09  -5.7 4.89e-01   1.3 2.72e-05 1.09e-01f  3
#  176 -5.4464538e+03 6.79e-05 1.05e+09  -5.7 3.45e-01   1.8 1.00e+00 2.12e-01h  2
#  177 -5.5038148e+03 6.50e-05 2.51e+08  -5.7 5.52e-01   1.3 1.04e-01 8.53e-02f  4
#  178 -5.5232932e+03 5.68e-05 1.60e+08  -5.7 2.86e-01   1.7 5.96e-01 1.58e-01f  3
#  179 -5.5435631e+03 5.49e-05 1.32e+08  -5.7 6.18e-01   1.2 2.08e-01 7.77e-02f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180 -5.5696546e+03 4.77e-05 1.02e+08  -5.7 3.13e-01   1.7 1.00e+00 1.65e-01f  3
#  181 -5.6033339e+03 5.74e-05 7.38e+07  -5.7 7.67e-01   1.2 2.47e-01 5.74e-02f  2
#  182 -5.6341903e+03 5.13e-05 5.69e+07  -5.7 3.49e-01   1.6 4.22e-01 1.23e-01f  3
#  183 -5.1127584e+03 9.14e-07 9.57e+07  -5.7 1.25e-01   2.0 1.00e+00 1.00e+00H  1
#  184 -5.4587551e+03 2.76e-05 6.26e+07  -5.7 3.40e-01   1.6 9.62e-01 1.92e-01f  2
#  185 -5.1035087e+03 8.67e-07 3.63e+08  -5.7 1.38e-01   2.0 3.82e-01 9.98e-01H  1
#  186 -5.1035087e+03 8.14e-07 8.07e+18  -5.7 2.75e-05  17.8 2.74e-02 6.07e-02h  1
# In iteration 186, 1 Slack too small, adjusting variable bound
#  187 -5.1035087e+03 8.14e-07 8.07e+18  -5.7 2.58e-05  17.3 1.14e-01 1.19e-07h  1
# In iteration 187, 1 Slack too small, adjusting variable bound
#  188 -5.1035087e+03 8.14e-07 8.07e+18  -5.7 2.58e-05  16.9 2.69e-01 3.43e-04h  1
#  189 -5.1035087e+03 8.08e-07 8.01e+18  -5.7 2.58e-05  16.4 1.63e-01 7.29e-03h  1
# In iteration 189, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190 -5.1035087e+03 8.08e-07 8.01e+18  -5.7 2.56e-05  15.9 9.32e-01 3.09e-05h  1
#  191 -5.1035087e+03 7.99e-07 7.92e+18  -5.7 2.56e-05  15.4 1.23e-01 1.07e-02h  1
#  192 -5.1035087e+03 7.91e-07 7.84e+18  -5.7 2.53e-05  15.0 1.00e+00 1.01e-02h  1
#  193 -5.1035087e+03 7.68e-07 7.61e+18  -5.7 2.51e-05  14.5 1.52e-01 2.98e-02h  1
#  194 -5.1035087e+03 7.57e-07 7.51e+18  -5.7 2.43e-05  14.0 1.00e+00 1.37e-02h  1
#  195 -5.1035087e+03 6.95e-07 6.90e+18  -5.7 2.40e-05  13.5 2.11e-01 8.20e-02h  1
#  196 -5.1035087e+03 6.89e-07 6.85e+18  -5.7 2.20e-05  14.0 1.00e+00 8.14e-03h  1
#  197 -5.1035087e+03 6.40e-07 6.37e+18  -5.7 2.19e-05  14.4 3.30e-01 7.14e-02h  1
# In iteration 197, 1 Slack too small, adjusting variable bound
#  198 -5.1035087e+03 6.39e-07 6.36e+18  -5.7 2.03e-05  15.7 1.00e+00 1.92e-03h  1
#  199 -5.1035087e+03 6.25e-07 6.22e+18  -5.7 2.03e-05  16.1 4.37e-01 2.20e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200 -5.1035087e+03 6.16e-07 6.13e+18  -5.7 1.98e-05  15.7 2.91e-01 1.42e-02h  1
#  201 -5.1035087e+03 6.00e-07 5.97e+18  -5.7 1.95e-05  15.2 1.00e+00 2.63e-02h  1
#  202 -5.1035086e+03 5.59e-07 5.57e+18  -5.7 1.90e-05  14.7 3.32e-01 6.89e-02h  1
#  203 -5.1035086e+03 5.25e-07 5.24e+18  -5.7 1.77e-05  14.2 1.00e+00 5.95e-02h  1
#  204 -5.1035086e+03 4.93e-07 4.92e+18  -5.7 1.67e-05  13.7 5.09e-01 6.20e-02h  1
#  205 -5.1035086e+03 4.44e-07 4.44e+18  -5.7 1.56e-05  13.3 6.63e-01 9.89e-02h  1
#  206 -5.1035086e+03 4.03e-07 4.04e+18  -5.7 1.41e-05  12.8 1.00e+00 9.33e-02h  1
#  207 -5.1035085e+03 3.60e-07 3.62e+18  -5.7 1.28e-05  12.3 1.00e+00 1.06e-01h  1
#  208 -5.1035085e+03 3.06e-07 3.10e+18  -5.7 1.14e-05  11.8 1.00e+00 1.51e-01h  1
#  209 -5.1035084e+03 2.53e-07 2.59e+18  -5.7 9.71e-06  11.4 8.61e-01 1.73e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210 -5.1035084e+03 1.87e-07 1.95e+18  -5.7 8.04e-06  10.9 1.00e+00 2.61e-01h  1
#  211 -5.1035084e+03 1.25e-07 1.36e+18  -5.7 5.94e-06  11.3 1.00e+00 3.31e-01h  1
#  212 -5.1035083e+03 8.96e-08 1.00e+18  -5.7 3.97e-06  10.8 7.92e-01 2.83e-01h  1
#  213 -5.1035083e+03 8.23e-08 9.23e+17  -5.7 2.84e-06  11.3 1.00e+00 8.14e-02f  4
#  214 -5.1035083e+03 2.75e-08 4.11e+17  -5.7 2.61e-06  10.8 1.00e+00 6.66e-01h  1
#  215 -5.1035083e+03 2.63e-11 1.03e+17  -5.7 8.74e-07  10.3 1.00e+00 1.00e+00f  1
#  216 -5.1035083e+03 2.52e-11 2.57e+16  -5.7 9.40e-09   9.8 1.00e+00 1.00e+00f  1
#  217 -5.1035083e+03 2.73e-11 6.42e+15  -5.7 3.58e-08   9.4 1.00e+00 1.00e+00f  1
#  218 -5.1035085e+03 2.69e-11 1.60e+15  -5.7 4.22e-08   8.9 1.00e+00 1.00e+00f  1
#  219 -5.1035091e+03 2.96e-11 4.01e+14  -5.7 9.96e-08   8.4 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220 -5.1035109e+03 2.63e-11 1.00e+14  -5.7 1.99e-07   7.9 1.00e+00 1.00e+00f  1
#  221 -5.1035163e+03 2.65e-11 2.51e+13  -5.7 4.75e-07   7.4 1.00e+00 1.00e+00f  1
#  222 -5.1035325e+03 3.00e-11 6.27e+12  -5.7 1.50e-06   7.0 1.00e+00 1.00e+00f  1
#  223 -5.1035812e+03 2.60e-11 1.57e+12  -5.7 4.56e-06   6.5 1.00e+00 1.00e+00f  1
#  224 -5.1037272e+03 2.48e-11 3.92e+11  -5.7 1.37e-05   6.0 5.97e-01 1.00e+00f  1
#  225 -5.1037272e+03 2.27e-11 9.79e+10  -5.7 6.18e-11  15.9 1.00e+00 1.00e+00h  1
#  226 -5.1072494e+03 1.63e-09 2.45e+10  -8.6 1.99e-03    -  1.43e-01 1.00e+00f  1
#  227 -5.1072494e+03 2.28e-11 6.12e+09  -8.6 8.89e-08  15.4 9.54e-01 1.00e+00h  1
#  228 -5.1072504e+03 3.14e-11 5.88e+09  -8.6 1.51e-05    -  7.57e-02 4.02e-02f  1
# In iteration 228, 1 Slack too small, adjusting variable bound
#  229 -5.1072513e+03 3.75e-11 5.69e+09  -8.6 1.46e-05    -  1.08e-01 3.28e-02f  1
# In iteration 229, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230 -5.1072554e+03 3.84e-11 4.86e+09  -8.6 1.44e-05    -  1.31e-01 1.51e-01f  1
# In iteration 230, 1 Slack too small, adjusting variable bound
#  231 -5.1072648e+03 3.82e-11 3.55e+09  -8.6 1.60e-05    -  1.90e-01 2.90e-01f  1
# In iteration 231, 1 Slack too small, adjusting variable bound
#  232 -5.1072859e+03 2.93e-11 2.09e+09  -8.6 2.22e-05    -  3.05e-01 4.65e-01f  1
# In iteration 232, 1 Slack too small, adjusting variable bound
#  233 -5.1073543e+03 2.67e-11 7.46e+08  -8.6 4.15e-05    -  3.83e-01 8.05e-01f  1
#  234 -5.1077901e+03 3.37e-10 1.86e+08  -8.6 2.13e-04    -  2.42e-01 1.00e+00f  1
#  235 -5.1077901e+03 2.52e-11 4.67e+07  -8.6 7.25e-09  14.9 1.00e+00 1.00e+00h  1
#  236 -5.1077901e+03 2.18e-11 1.16e+07  -8.6 2.78e-11  16.2 1.00e+00 1.00e+00h  1
#  237 -5.1077901e+03 2.18e-11 2.91e+06  -8.6 2.09e-11  15.8 1.00e+00 1.00e+00h  1
#  238 -5.1077901e+03 2.17e-11 7.27e+05  -8.6 2.10e-11  15.3 1.00e+00 1.00e+00h  1
#  239 -5.1077901e+03 2.18e-11 1.82e+05  -8.6 2.09e-11  14.8 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240 -5.1077901e+03 2.24e-11 4.54e+04 -11.0 2.09e-11  14.3 1.00e+00 1.00e+00h  1
#  241 -5.1077901e+03 2.17e-11 1.14e+04 -11.0 2.80e-11  13.8 1.00e+00 1.00e+00h  1
#  242 -5.1077901e+03 2.18e-11 2.84e+03 -11.0 2.09e-11  13.4 1.00e+00 1.00e+00h  1
#  243 -5.1077901e+03 2.09e-11 7.11e+02 -11.0 2.09e-11  12.9 1.00e+00 1.00e+00h  1
#  244 -5.1077901e+03 1.97e-11 1.76e+02 -11.0 2.09e-11  12.4 1.00e+00 1.00e+00h  1
#  245 -5.1077901e+03 1.93e-11 1.32e+02 -11.0 1.63e-11  11.9 1.00e+00 1.00e+00h  1
#  246 -5.1077901e+03 2.11e-11 8.09e+03 -11.0 4.20e-11  11.5 1.00e+00 1.00e+00h  1
#  247 -5.1077901e+03 2.25e-11 1.62e+09 -11.0 2.12e-11  19.3 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 247
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -5.1077900888130398e+03   -5.1077900888130398e+03
# Dual infeasibility......:   1.6201580261582363e+09    1.6201580261582363e+09
# Constraint violation....:   9.0818314025242374e-14    2.2546388367405964e-11
# Variable bound violation:   9.9613826493039070e-09    9.9613826493039070e-09
# Complementarity.........:   9.0971266975597463e-12    9.0971266975597463e-12
# Overall NLP error.......:   7.3121430369590870e-08    1.6201580261582363e+09
#
#
# Number of objective function evaluations             = 361
# Number of objective gradient evaluations             = 248
# Number of equality constraint evaluations            = 361
# Number of inequality constraint evaluations          = 361
# Number of equality constraint Jacobian evaluations   = 248
# Number of inequality constraint Jacobian evaluations = 248
# Number of Lagrangian Hessian evaluations             = 247
# Total seconds in IPOPT                               = 32.723
#
# EXIT: Solved To Acceptable Level.
# Dict{String, Any} with 8 entries:
#   "solve_time"         => 33.8263
#   "optimizer"          => "Ipopt"
#   "termination_status" => ALMOST_LOCALLY_SOLVED
#   "dual_status"        => NEARLY_FEASIBLE_POINT
#   "primal_status"      => NEARLY_FEASIBLE_POINT
#   "objective"          => -5107.79
#   "solution"           => Dict{String, Any}("nw"=>Dict{String, Dict{String, Any…
#   "objective_lb"       => -Inf

# %%
########################
# avaliando resultados #
########################
line2_active_power = []
line3_active_power = []

load1_active_power = []
load2_active_power = []

pv1_active_power = []
pv2_active_power = []

bess_1_active_power = []
bess_2_active_power = []
bess_1_state = []
bess_2_state = []

bus_n3_1_voltage = []
bus_n3_2_voltage = []
bus_n3_3_voltage = []

for i in 1:96
    # line
    push!(line2_active_power, sum(result["solution"]["nw"]["$i"]["line"]["line2"]["pt"]))
    push!(line3_active_power, sum(result["solution"]["nw"]["$i"]["line"]["line3"]["pt"]))

    # load
    push!(load1_active_power, sum(result["solution"]["nw"]["$i"]["load"]["load1"]["pd"]))
    push!(load2_active_power, sum(result["solution"]["nw"]["$i"]["load"]["load2"]["pd"]))

    # solar
    push!(pv1_active_power, .- sum(result["solution"]["nw"]["$i"]["solar"]["pv1"]["pg"]))
    push!(pv2_active_power, .- sum(result["solution"]["nw"]["$i"]["solar"]["pv2"]["pg"]))

    # bess
    push!(bess_1_active_power, sum(result["solution"]["nw"]["$i"]["storage"]["bess_1"]["ps"]))
    push!(bess_1_state, result["solution"]["nw"]["$i"]["storage"]["bess_1"]["se"])
    push!(bess_2_active_power, sum(result["solution"]["nw"]["$i"]["storage"]["bess_2"]["ps"]))
    push!(bess_2_state, result["solution"]["nw"]["$i"]["storage"]["bess_2"]["se"])

    # bus
    push!(bus_n3_1_voltage, result["solution"]["nw"]["$i"]["bus"]["n4"]["vm"][1])
    push!(bus_n3_2_voltage, result["solution"]["nw"]["$i"]["bus"]["n4"]["vm"][2])
    push!(bus_n3_3_voltage, result["solution"]["nw"]["$i"]["bus"]["n4"]["vm"][3])

end

#######################################
# plotagem de graficos para validacao #
#######################################
time = time_indexes ./ 4
bar(time, load1_active_power + load2_active_power, label="Carga 1", linewidth=0.5)
bar!(time, pv1_active_power + pv2_active_power, label="Sistema FV", linewidth=0.5)
bar!(time, bess_1_active_power + bess_2_active_power, label="Armazenamento", linewidth=0.5)
bar!(time, line2_active_power + line3_active_power, label="Fluxo na Linha", linewidth=0.5)
title!("Potência Ativa dos Componentes")
xlabel!("Tempo (h)")
ylabel!("Potência (W)")
savefig(results_path * "potencia_ativa.png")

bar(time, pv1_active_power .+ pv2_active_power .+
          bess_1_active_power .+ bess_2_active_power .+
          load1_active_power .+ load2_active_power,
          label="Balanço no barramento", linewidth=0.5)
bar!(time, line2_active_power .+ line3_active_power, label="Fluxo na Linha", linewidth=0.5)
title!("Comparacao balanço e fluxo na linha")
xlabel!("Tempo (h)")
ylabel!("Potência (W)")
savefig(results_path * "validacao_linha.png")


plot(time, bess_1_active_power, 
    label="Potência Ativa (W)", 
    ylabel="Potência Ativa (W)",
    legend=:topright)
plot!(twinx(), time, bess_1_state, 
    label="Estado do Armazenamento (Wh)", 
    color=:red,
    ylabel="Estado de Carga (Wh)",
    legend=:topleft)
title!("Potência Ativa e Estado do Armazenamento")
savefig(results_path * "estado_armazenamento_ativo_1.png")
    

plot(time, bess_2_active_power, 
    label="Potência Ativa (W)", 
    ylabel="Potência Ativa (W)",
    legend=:topright)
plot!(twinx(), time, bess_2_state, 
    label="Estado do Armazenamento (Wh)", 
    color=:red,
    ylabel="Estado de Carga (Wh)",
    legend=:topleft)
title!("Potência Ativa e Estado do Armazenamento")
savefig(results_path * "estado_armazenamento_ativo_2.png")


plot(time, bus_n3_1_voltage, label="Tensão na Fase 1", linewidth=2)
plot!(time, bus_n3_2_voltage, label="Tensão na Fase 2", linewidth=2)
plot!(time, bus_n3_3_voltage, label="Tensão na Fase 3", linewidth=2)
title!("Tensão nas fases (barramento n3)")
xlabel!("Tempo (h)")
ylabel!("Tensão em Kv")
savefig(results_path * "tensao_barramento.png")
    
plot(time, gen_data.pgen .* (750), linewidth=2)
bar!(time, .- pv1_active_power, linewidth=2)
bar!(time, .- pv2_active_power, linewidth=2)
title!("Geração nominal solar")
xlabel!("Tempo (h)")
ylabel!("Tensão em Kv")
savefig(results_path * "geracao em PU.png")
# Out:
# "/home/luizfreire/Documents/mestrado/powerModelsExemplos/results/2025-04-21_solar_carga_armazenamento_opf_cost/geracao em PU.png"

# %% [markdown]
# ## Experimento com geração nominal de 1500W para fonte fotovoltaica

# %%
eng_model = PowerModelsDistribution.parse_file("4Bus-DY-Bal/4Bus-DY-Bal.DSS")

#######################################
# adicionando série temporal de carga #
#######################################
# o passo da análise será de 15 minutos
# coletando 24horas de dados
time_indexes = Float64.(collect(1:96))


############################
# adicionando um novo bus #
############################
add_bus!(eng_model,
         "n5",
         rg=[0.0],
         grounded=[4],
         status=ENABLED,
         terminals=[1, 2, 3, 4],
         xg=[0.0])


##########################
# adicionando nova linha #
##########################
line3 = copy(eng_model["line"]["line2"])
line3["f_bus"] = "n3"
line3["t_bus"] = "n5"
eng_model["line"]["line3"] = line3


##########################
# adicionando nova carga #
##########################
add_load!(eng_model,
          "load2",
          "n5",
          [1, 2, 3, 4],
          pd_nom=[1800.0, 1800.0, 1800.0],
          configuration=WYE,
          status=ENABLED,
          vm_nom=2.40178,
          dispatchable=NO,
          qd_nom=[871.78, 871.78, 871.78])

# definindo a série temporal de carga ativa
# o parametro replace indica se a serie irá mutiplicar a potencia nominal ou substituir
# caso seja false, ela irá mutiplicar (caso a serie temporal esteja em PU)
pd_ts_l1 = Dict("time" => time_indexes,
                "values" => load_data.pload,
                "offset" => 0,
                "replace" => false)

# definindo a série temporal de carga reativa
qd_ts_l1 = Dict("time" => time_indexes,
                "values" => load_data.qload,
                "offset" => 0,
                "replace" => false)

# indicando a série temporal designada para carga load1
eng_model["time_series"] = Dict("pd_ts_l1" => pd_ts_l1, "qd_ts_l1" => qd_ts_l1)
eng_model["load"]["load1"]["time_series"] = Dict("pd_nom" => "pd_ts_l1",
                                                 "qd_nom" => "qd_ts_l1")

eng_model["time_series"] = Dict("pd_ts_l1" => pd_ts_l1, "qd_ts_l1" => qd_ts_l1)
eng_model["load"]["load2"]["time_series"] = Dict("pd_nom" => "pd_ts_l1",
                                                 "qd_nom" => "qd_ts_l1")


#########################################
# adicionando série temporal de geracao #
#########################################
# definindo que a série temporal é a mesma para cada uma das fases
gen_data_1 = []
for i in gen_data.pgen
    push!(gen_data_1, [i, i, i, 0])
end

# definindo a série temporal de geração
pd_ts_g1 = Dict("time" => time_indexes,
                "values" => gen_data_1,
                "offset" => 0,
                "replace" => false)

# adicionando um sistema fotovoltaico
add_solar!(eng_model,
           "pv1",
           "n4",
           configuration=WYE,
           [1, 2, 3, 4],
           pg=[500, 500, 500, 0],
           qg=[0, 0, 0, 0],
           pg_ub=[500, 500, 500, 0], # potencia ativa nominal
           pg_lb=[0, 0, 0, 0], # limite inferior de potencia ativa
           qg_ub=[0, 0, 0, 0], # potencia reativa nominal
           qg_lb=[0, 0, 0, 0]) # limite inferior de potencia reativa
eng_model["time_series"]["pd_ts_g1"] = pd_ts_g1
eng_model["solar"]["pv1"]["time_series"] = Dict("pg_ub" => "pd_ts_g1",
                                                "pg_lb" => "pd_ts_g1")

add_solar!(eng_model,
           "pv2",
           "n5",
           configuration=WYE,
           [1, 2, 3, 4],
           pg=[500, 500, 500, 0],
           qg=[0, 0, 0, 0],
           pg_ub=[500, 500, 500, 0], # potencia ativa nominal
           pg_lb=[0, 0, 0, 0], # limite inferior de potencia ativa
           qg_ub=[0, 0, 0, 0], # potencia reativa nominal
           qg_lb=[0, 0, 0, 0]) # limite inferior de potencia reativa
eng_model["time_series"]["pd_ts_g1"] = pd_ts_g1
eng_model["solar"]["pv2"]["time_series"] = Dict("pg_ub" => "pd_ts_g1",
                                                "pg_lb" => "pd_ts_g1")


#############################
# adicionando armazenamento #
#############################
add_storage!(eng_model,
             "bess_1",
             "n4",
             configuration=WYE,
             [1, 2, 3, 4],
             energy=40000,
             energy_ub=80000,
             charge_ub=7000,
             discharge_ub=7000,
             sm_ub=150000,
             cm_ub=1e6,
             qex=0,
             pex=0,
             charge_efficiency=100,
             discharge_efficiency=100,
             qs_ub=0,
             qs_lb=0,
             rs=0,
             xs=0)

add_storage!(eng_model,
             "bess_2",
             "n5",
             configuration=WYE,
             [1, 2, 3, 4],
             energy=40000,
             energy_ub=80000,
             charge_ub=7000,
             discharge_ub=7000,
             sm_ub=150000,
             cm_ub=1e6,
             qex=0,
             pex=0,
             charge_efficiency=100,
             discharge_efficiency=100,
             qs_ub=0,
             qs_lb=0,
             rs=0,
             xs=0)

eng_model["settings"]["sbase_default"] = 1000

# venda / compra
eng_model["voltage_source"]["source"]["cost_pg_parameters"] = [-100, 100]

eng_model["solar"]["pv1"]["cost_pg_parameters"] = [50, 50]
eng_model["solar"]["pv2"]["cost_pg_parameters"] = [50, 50]

eng_model["storage"]["bess_1"]["cost"] = [30, 50]
eng_model["storage"]["bess_2"]["cost"] = [30, 50]
# Out:
# [ PowerModelsDistribution | Info ] : Command 'calcvoltagebases' on line 36 in '4Bus-DY-Bal.DSS' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : Command 'solve' on line 37 in '4Bus-DY-Bal.DSS' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : basemva=100 is the default value, you may want to adjust sbase_default for better convergence
# 2-element Vector{Int64}:
#  30
#  50

# %%
eng_model = make_multinetwork(eng_model) # indicando que se trata de uma série temporal
set_time_elapsed!(eng_model, 0.25) # indicando que o passo é de 15 minutos 
result = solve_mc_model(eng_model, ACPUPowerModel, Ipopt.Optimizer, build_mc_mn_opf_cost; multinetwork=true)
# Out:
# [ PowerModelsDistribution | Info ] : assuming time is in hours for time_elapsed inference. if this is incorrect, manually adjust with set_time_elapsed!
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:   117184
# Number of nonzeros in inequality constraint Jacobian.:    14400
# Number of nonzeros in Lagrangian Hessian.............:   272388
#
# Total number of variables............................:    18306
#                      variables with only lower bounds:     2592
#                 variables with lower and upper bounds:     4194
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    17184
# Total number of inequality constraints...............:     5952
#         inequality constraints with only lower bounds:     2016
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:     3936
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -3.7943910e+03 5.24e+00 5.00e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -3.7796277e+03 5.22e+00 1.00e+02  -1.0 5.75e+00   2.0 3.07e-01 3.52e-03h  1
#    2 -3.5785004e+03 4.97e+00 6.55e+02  -1.0 5.73e+00   2.4 4.80e-01 4.65e-02h  1
#    3 -3.0798845e+03 4.26e+00 4.24e+02  -1.0 5.46e+00   1.9 7.31e-01 1.44e-01h  1
#    4 -2.8288467e+03 3.99e+00 7.28e+02  -1.0 4.71e+00   2.4 6.08e-01 6.29e-02h  1
#    5 -2.3209199e+03 3.37e+00 2.55e+02  -1.0 4.42e+00   1.9 9.90e-01 1.57e-01h  1
#    6 -2.2436383e+03 3.29e+00 2.67e+02  -1.0 3.75e+00   2.3 2.25e-02 2.15e-02h  1
#    7 -2.1652002e+03 3.19e+00 5.77e+02  -1.0 3.66e+00   1.8 9.62e-02 3.23e-02h  1
#    8 -1.9485388e+03 2.98e+00 1.85e+03  -1.0 3.55e+00   2.3 1.21e-01 6.34e-02h  1
#    9 -1.8386808e+03 2.83e+00 6.14e+03  -1.0 3.32e+00   1.8 6.72e-02 5.15e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -1.6659089e+03 2.65e+00 1.69e+05  -1.0 3.15e+00   2.2 1.11e-01 6.30e-02h  1
#   11 -1.5613728e+03 2.47e+00 1.09e+06  -1.0 2.95e+00   1.7 2.25e-01 6.99e-02h  1
#   12 -1.3006530e+03 2.19e+00 2.18e+06  -1.0 2.74e+00   2.2 3.04e-01 1.11e-01h  1
#   13 -1.0541866e+03 1.98e+00 2.08e+06  -1.0 2.44e+00   2.6 1.29e-01 9.76e-02h  1
#   14 -8.7125443e+02 1.77e+00 2.33e+06  -1.0 2.20e+00   2.1 2.06e-01 1.06e-01h  1
#   15 -6.2419821e+02 1.55e+00 2.82e+06  -1.0 1.97e+00   2.5 3.22e-01 1.25e-01h  1
#   16 -4.6287354e+02 1.35e+00 2.99e+06  -1.0 1.72e+00   2.1 3.23e-01 1.27e-01h  1
#   17 -2.1843129e+02 1.13e+00 2.87e+06  -1.0 1.50e+00   2.5 3.79e-01 1.65e-01h  1
#   18 -1.7743145e+01 9.71e-01 2.66e+06  -1.0 1.25e+00   2.9 3.36e-01 1.40e-01h  1
#   19  1.2432903e+02 8.32e-01 2.55e+06  -1.0 1.07e+00   2.4 5.98e-01 1.44e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  3.8527718e+02 6.27e-01 1.94e+06  -1.0 9.17e-01   2.9 3.75e-01 2.46e-01h  1
#   21  5.3845623e+02 5.16e-01 1.60e+06  -1.0 6.89e-01   3.3 2.84e-01 1.77e-01h  1
#   22  6.9980922e+02 3.81e-01 2.05e+06  -1.0 5.67e-01   2.8 8.14e-01 2.61e-01h  1
#   23  8.9428933e+02 2.37e-01 1.79e+06  -1.0 4.19e-01   3.2 6.81e-01 3.78e-01h  1
#   24  1.0435329e+03 1.31e-01 1.84e+06  -1.0 2.60e-01   3.7 1.00e+00 4.47e-01h  1
#   25  1.1173451e+03 6.15e-02 1.52e+06  -1.0 1.44e-01   3.2 1.00e+00 5.31e-01h  1
#   26  1.1662754e+03 1.88e-02 1.15e+06  -1.0 6.76e-02   3.6 1.00e+00 6.95e-01h  1
#   27  1.1492172e+03 7.11e-03 1.61e+06  -1.0 3.60e-02   3.1 1.00e+00 6.21e-01f  1
#   28  1.1398365e+03 5.66e-04 3.04e+05  -1.0 1.37e-02   3.6 1.00e+00 9.20e-01h  1
#   29  1.0847609e+03 5.26e-05 4.93e+05  -1.0 2.79e-02   3.1 1.00e+00 9.07e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  9.7403949e+02 1.98e-05 2.22e+06  -1.0 8.16e-02   2.6 1.00e+00 6.22e-01f  1
#   31  7.4666972e+02 1.21e-05 2.96e+06  -1.0 2.37e-01   2.1 1.00e+00 4.24e-01f  1
#   32  6.2126758e+02 4.68e-06 1.54e+06  -1.0 9.09e-02   2.6 1.00e+00 6.64e-01f  1
#   33  3.8137658e+02 2.08e-05 1.25e+06  -1.0 2.63e-01   2.1 7.04e-01 4.89e-01f  1
#   34  2.1253272e+02 6.44e-06 9.49e+05  -1.0 1.01e-01   2.5 1.00e+00 7.73e-01f  1
#   35  5.2460543e+01 8.41e-06 1.08e+06  -1.0 2.94e-01   2.0 4.24e-01 2.72e-01f  1
#   36  2.5839645e+01 7.65e-06 1.64e+06  -1.0 1.14e-01   2.5 2.55e-01 9.46e-02f  1
#   37 -2.7455982e+00 7.42e-06 6.53e+06  -1.0 3.28e-01   2.0 1.00e+00 3.76e-02f  1
#   38 -1.6798891e+02 1.36e-05 8.18e+07  -1.0 1.28e-01   2.4 1.18e-01 1.00e+00f  1
#   39 -5.6456264e+02 5.42e-05 3.31e+07  -1.0 3.60e-01   1.9 1.00e+00 7.59e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40 -8.6285451e+02 2.32e-05 5.27e+07  -1.0 1.43e-01   2.4 7.29e-01 9.59e-01f  1
#   41 -1.0214741e+03 1.89e-05 3.12e+07  -1.0 3.95e-01   1.9 5.46e-01 2.14e-01f  1
#   42 -1.0599203e+03 1.68e-05 1.99e+07  -1.0 1.64e-01   2.3 3.34e-01 1.18e-01f  1
#   43 -1.2053345e+03 2.06e-05 1.14e+07  -1.0 4.68e-01   1.8 1.00e+00 2.65e-01f  1
#   44 -1.3637423e+03 2.35e-05 1.27e+09  -1.0 1.61e-01   2.3 2.31e-01 8.12e-01f  1
#   45 -1.5018662e+03 2.03e-05 1.07e+09  -1.0 4.10e-01   1.8 7.45e-01 1.66e-01f  1
#   46 -1.6955568e+03 2.48e-05 9.15e+08  -1.0 1.34e+00   1.3 8.66e-01 1.49e-01f  1
#   47 -1.9064873e+03 1.14e-04 5.04e+08  -1.0 4.76e-01   1.7 7.06e-01 5.17e-01f  1
#   48 -2.0564523e+03 1.18e-03 1.26e+08  -1.0 1.32e+00   1.2 4.07e-01 1.00e+00f  1
#   49 -2.9770641e+03 2.31e-04 4.18e+07  -1.0 4.11e-01   1.7 5.97e-01 8.46e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -3.0810337e+03 2.21e-04 4.07e+07  -1.0 1.02e+00   1.2 2.92e-01 4.40e-02f  1
#   51 -3.5085300e+03 5.58e-04 4.88e+07  -1.0 4.85e-01   1.6 2.46e-01 9.74e-01f  1
#   52 -3.6497643e+03 3.98e-04 3.13e+07  -1.0 1.72e-01   2.1 5.67e-01 2.89e-01f  1
#   53 -3.8350962e+03 4.60e-04 7.14e+10  -1.0 4.98e-01   1.6 3.53e-02 1.00e+00f  1
#   54 -3.8351341e+03 4.52e-04 7.01e+10  -1.0 2.58e-02  11.4 2.10e-02 1.82e-02h  1
#   55 -3.8351898e+03 4.39e-04 6.82e+10  -1.0 2.54e-02  10.9 3.86e-02 2.72e-02h  1
#   56 -3.8353274e+03 4.09e-04 6.35e+10  -1.0 2.47e-02  10.5 7.81e-03 6.92e-02f  1
#   57 -3.8361167e+03 2.34e-04 3.63e+10  -1.0 2.30e-02  10.0 1.00e+00 4.28e-01f  1
#   58 -3.8361837e+03 2.19e-04 3.40e+10  -1.0 1.31e-02  10.4 1.83e-02 6.38e-02h  1
#   59 -3.8371681e+03 1.34e-08 4.53e+09  -1.0 1.23e-02   9.9 1.30e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -3.8371687e+03 2.39e-11 5.28e+08  -1.0 8.93e-06   9.5 1.00e+00 1.00e+00h  1
#   61 -3.8371687e+03 2.98e-11 2.63e+07  -1.0 4.53e-07   9.0 1.00e+00 1.00e+00f  1
#   62 -3.8371687e+03 2.62e-11 4.83e+08  -1.0 1.36e-06   8.5 1.00e+00 1.00e+00f  1
#   63 -3.8371688e+03 2.99e-11 3.70e+08  -1.0 3.16e-06   8.0 1.00e+00 2.50e-01f  3
#   64 -3.8371692e+03 2.38e-11 7.66e+07  -1.0 7.11e-06   7.5 1.00e+00 1.00e+00f  1
#   65 -3.8371714e+03 2.46e-11 5.47e+07  -1.0 1.31e-05   7.1 1.00e+00 1.00e+00f  1
#   66 -3.8371796e+03 2.36e-11 1.09e+08  -1.0 2.71e-05   6.6 1.00e+00 1.00e+00f  1
#   67 -3.8372092e+03 2.55e-11 2.30e+08  -1.0 5.88e-05   6.1 1.00e+00 1.00e+00f  1
#   68 -3.8373136e+03 5.06e-11 1.11e+08  -1.0 1.73e-04   5.6 1.00e+00 1.00e+00f  1
#   69 -3.8376880e+03 1.49e-10 2.25e+08  -1.0 4.92e-04   5.2 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70 -3.8390514e+03 8.88e-10 7.56e+08  -1.0 1.32e-03   4.7 1.00e+00 1.00e+00f  1
#   71 -3.8438278e+03 6.30e-09 1.57e+08  -1.0 3.37e-03   4.2 1.00e+00 1.00e+00f  1
#   72 -3.8592492e+03 4.77e-08 3.03e+08  -1.0 8.61e-03   3.7 1.00e+00 1.00e+00f  1
#   73 -3.9050139e+03 3.97e-07 8.89e+09  -1.0 2.20e-02   3.3 1.00e+00 1.00e+00f  1
#   74 -3.9456217e+03 6.73e-07 6.18e+09  -1.0 3.07e-02   2.8 1.00e+00 3.29e-01f  1
#   75 -4.1790686e+03 3.18e-05 1.23e+09  -1.0 8.96e-02   2.3 1.00e+00 1.00e+00f  1
#   76 -4.3819423e+03 1.30e-04 1.12e+09  -1.0 2.74e-01   1.8 1.00e+00 1.00e+00f  1
#   77 -4.2387584e+03 3.38e-05 3.92e+09  -1.0 7.57e-01   1.3 1.00e+00 1.00e+00H  1
#   78 -4.2414208e+03 2.22e-08 2.85e+10  -1.0 2.02e-03   4.5 1.00e+00 1.00e+00f  1
#   79 -4.2424196e+03 6.97e-09 1.53e+10  -1.0 1.13e-03   4.9 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80 -4.2454681e+03 2.07e-09 2.26e+09  -1.0 7.64e-04   4.4 1.00e+00 1.00e+00f  1
#   81 -4.2549231e+03 1.46e-08 2.82e+08  -1.0 1.92e-03   4.0 1.00e+00 1.00e+00f  1
#   82 -4.2839019e+03 1.08e-07 8.13e+07  -1.0 4.96e-03   3.5 1.00e+00 1.00e+00f  1
#   83 -4.3664859e+03 9.14e-07 4.76e+07  -1.0 1.60e-02   3.0 8.43e-01 1.00e+00f  1
#   84 -4.4465582e+03 1.70e-06 2.26e+07  -1.0 4.15e-02   2.5 1.00e+00 3.52e-01f  1
#   85 -4.7292544e+03 5.71e-05 1.23e+09  -1.0 1.24e-01   2.0 1.91e-01 1.00e+00f  1
#   86 -4.9971644e+03 7.03e-05 7.65e+08  -1.0 3.60e-01   1.6 4.86e-01 3.22e-01f  1
#   87 -4.9232669e+03 1.04e-06 2.55e+10  -1.0 1.22e-01   2.0 1.23e-01 1.00e+00H  1
#   88 -5.1840746e+03 1.04e-04 4.05e+09  -1.0 3.05e-01   1.5 8.26e-01 4.08e-01f  1
#   89 -5.3207773e+03 6.68e-05 3.47e+10  -1.0 1.39e-01   1.9 1.00e+00 3.59e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90 -4.3604936e+03 1.49e-05 1.95e+12  -1.0 3.98e-01   1.5 3.83e-02 1.00e+00H  1
#   91 -4.5276242e+03 1.45e-05 1.62e+12  -1.0 2.45e-01   1.9 9.81e-01 1.57e-01f  1
#   92 -5.0923673e+03 7.06e-05 5.63e+12  -1.0 4.77e-01   1.4 1.00e+00 3.63e-01F  1
#   93 -5.1665961e+03 2.14e-06 9.50e+12  -1.0 1.48e-01   1.8 5.49e-01 1.00e+00F  1
#   94 -5.4303921e+03 5.32e-06 1.88e+12  -1.0 5.18e-01   1.4 1.00e+00 8.73e-02f  1
#   95 -5.6398532e+03 4.70e-05 1.23e+13  -1.0 2.02e-01   1.8 3.36e-01 4.76e-01f  2
#   96 -5.6521944e+03 5.24e-08 3.63e+14  -1.0 5.58e-03   4.0 1.00e+00 1.00e+00f  1
#   97 -5.6569800e+03 6.82e-09 8.68e+13  -1.0 1.34e-03   4.4 9.65e-01 1.00e+00f  1
#   98 -5.6697432e+03 1.71e-08 8.16e+12  -1.0 2.03e-03   4.0 1.00e+00 1.00e+00f  1
#   99 -5.7018159e+03 1.55e-07 3.22e+12  -1.0 6.19e-03   3.5 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100 -5.7769145e+03 1.43e-06 7.21e+11  -1.0 1.94e-02   3.0 1.00e+00 1.00e+00f  1
#  101 -5.8143078e+03 1.11e-05 8.04e+12  -1.0 3.73e-02   2.5 3.63e-01 1.00e+00f  1
#  102 -5.8160448e+03 2.17e-05 4.27e+11  -1.0 1.11e-01   2.1 1.00e+00 4.68e-01f  1
#  103 -4.5388940e+03 1.31e-05 8.57e+14  -1.0 2.79e-01   1.6 5.22e-02 1.00e+00H  1
#  104 -4.7270901e+03 1.17e-05 7.17e+14  -1.0 1.77e-01   2.0 1.00e+00 1.70e-01f  1
#  105 -4.9848853e+03 1.32e-05 6.33e+14  -1.0 3.03e-01   1.5 3.59e-01 1.22e-01f  3
#  106 -5.5321895e+03 6.07e-06 1.48e+14  -1.0 1.14e-01   2.0 1.00e+00 9.64e-01F  1
#  107 -5.8430395e+03 3.34e-05 1.20e+14  -1.0 3.46e-01   1.5 5.26e-01 1.93e-01f  2
#  108 -6.0022894e+03 3.71e-05 8.92e+13  -1.0 1.60e-01   1.9 1.22e-01 2.77e-01f  2
#  109 -6.0495520e+03 3.48e-05 8.02e+13  -1.0 4.64e-01   1.4 1.00e+00 1.03e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110 -6.1044804e+03 2.86e-05 6.46e+13  -1.0 1.62e-01   1.9 4.47e-02 1.93e-01f  3
#  111 -6.1510518e+03 2.81e-05 6.28e+13  -1.0 3.82e-01   1.4 1.00e+00 2.73e-02f  1
#  112 -5.0811914e+03 1.58e-05 4.80e+15  -1.0 1.76e-01   1.8 4.32e-02 9.37e-01H  1
#  113 -5.0813496e+03 8.26e-09 8.14e+15  -1.0 6.84e-03   6.7 1.00e+00 1.00e+00f  1
#  114 -5.0813459e+03 8.17e-09 7.80e+15  -1.0 2.97e-02   6.3 3.94e-01 3.42e-02h  3
#  115 -5.0813501e+03 6.19e-09 5.77e+15  -1.0 2.25e-03   6.7 1.00e+00 2.50e-01f  3
#  116 -5.0813615e+03 5.24e-09 4.72e+15  -1.0 3.82e-03   6.2 1.00e+00 1.74e-01f  3
#  117 -5.0813765e+03 5.26e-09 4.30e+15  -1.0 8.10e-03   5.7 1.00e+00 8.39e-02f  3
#  118 -5.0813584e+03 8.95e-08 3.42e+15  -1.0 4.33e-02   5.3 5.12e-01 1.07e-01f  2
#  119 -5.0819481e+03 4.66e-07 1.16e+15  -1.0 2.52e-02   4.8 1.00e+00 3.54e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120 -5.0889503e+03 4.42e-09 1.67e+13  -1.0 1.48e-03   4.3 1.00e+00 1.00e+00f  1
#  121 -5.1092308e+03 2.22e-08 1.56e+12  -1.0 3.26e-03   3.8 1.00e+00 1.00e+00f  1
#  122 -5.1666479e+03 2.23e-07 2.71e+11  -1.0 7.63e-03   3.4 1.00e+00 1.00e+00f  1
#  123 -5.3294444e+03 2.13e-06 3.52e+10  -1.0 2.25e-02   2.9 1.00e+00 1.00e+00f  1
#  124 -5.7355003e+03 6.86e-08 1.41e+12  -1.0 6.48e-02   2.4 3.07e-01 1.00e+00F  1
#  125 -5.9041160e+03 3.75e-06 2.57e+10  -1.0 1.39e-01   1.9 1.00e+00 1.70e-01f  1
#  126 -6.0515325e+03 1.48e-05 1.44e+12  -1.0 4.17e-01   1.4 9.62e-01 1.09e-01f  3
#  127 -6.1537536e+03 1.58e-05 1.10e+12  -1.0 1.60e-01   1.9 5.81e-01 1.65e-01f  2
#  128 -6.1955776e+03 1.67e-05 9.54e+11  -1.0 5.18e-01   1.4 1.00e+00 2.75e-02f  1
#  129 -6.2119210e+03 1.61e-05 8.52e+11  -1.0 1.65e-01   1.8 4.75e-01 7.63e-02f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130 -6.2319545e+03 1.64e-05 7.21e+11  -1.0 3.85e-01   1.3 6.11e-02 2.99e-02f  5
#  131 -6.2529195e+03 1.64e-05 7.00e+11  -1.0 2.75e-01   1.8 7.13e-01 2.88e-02f  1
#  132 -6.2619336e+03 1.67e-05 6.85e+11  -1.0 5.45e-01   1.3 1.73e-01 1.83e-02f  6
#  133 -6.2692285e+03 1.64e-05 6.61e+11  -1.0 2.11e-01   1.7 8.20e-02 2.53e-02f  3
#  134 -6.2733399e+03 1.64e-05 3.01e+13  -1.0 6.48e-01   1.2 9.59e-01 1.46e-02f  2
#  135 -6.2681988e+03 1.63e-05 2.91e+13  -1.0 2.50e-01   1.7 8.12e-01 3.10e-02h  5
#  136 -6.2755633e+03 1.68e-05 2.86e+13  -1.0 6.58e-01   1.2 9.60e-01 1.68e-02f  4
#  137 -6.2764921e+03 1.68e-05 2.77e+13  -1.0 2.81e-01   1.6 9.51e-01 3.31e-02f  2
#  138 -6.2202487e+03 1.70e-05 2.37e+13  -1.0 1.37e-01   2.0 7.78e-01 1.46e-01h  2
#  139 -6.2866291e+03 1.70e-05 2.29e+13  -1.0 3.63e-01   1.6 1.00e+00 3.58e-02f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140 -5.4949438e+03 1.21e-05 2.62e+11  -1.0 1.70e-01   2.0 9.66e-01 8.44e-01H  1
#  141 -5.6316505e+03 1.25e-05 1.98e+11  -1.0 5.91e-01   1.5 5.24e-01 4.12e-02f  1
#  142 -5.8232465e+03 1.31e-05 1.02e+16  -1.0 2.61e-01   1.9 1.02e-03 1.39e-01f  3
#  143 -5.8232455e+03 1.26e-05 9.52e+15  -1.0 1.17e-01   6.0 8.21e-01 3.52e-02h  1
#  144 -5.8231989e+03 1.23e-05 9.26e+15  -1.0 1.19e-01   5.5 2.57e-01 1.99e-02h  1
#  145 -5.8232637e+03 5.18e-06 3.36e+15  -1.0 4.74e-03   5.9 1.00e+00 5.81e-01f  1
#  146 -5.8237922e+03 1.67e-09 4.42e+13  -1.0 4.60e-04   5.5 1.00e+00 1.00e+00f  1
#  147 -5.8255247e+03 5.58e-10 7.31e+11  -1.0 6.04e-04   5.0 1.00e+00 1.00e+00f  1
#  148 -5.8306125e+03 9.92e-09 1.30e+12  -1.0 2.81e-03   4.5 1.00e+00 1.00e+00f  1
#  149 -5.8457889e+03 1.99e-08 8.54e+11  -1.0 2.46e-03   4.0 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150 -5.8894272e+03 1.36e-07 1.35e+12  -1.0 6.95e-03   3.5 1.00e+00 1.00e+00f  1
#  151 -6.0106935e+03 9.05e-07 9.50e+11  -1.0 2.10e-02   3.1 1.00e+00 1.00e+00f  1
#  152 -6.1453504e+03 3.56e-06 2.52e+11  -1.0 5.48e-02   2.6 1.00e+00 6.57e-01f  1
#  153 -6.1422074e+03 1.89e-05 2.52e+11  -1.0 9.32e-02   2.1 3.14e-01 5.00e-01f  2
#  154 -6.2396209e+03 1.96e-05 2.25e+11  -1.0 3.19e-01   1.6 4.57e-01 6.73e-02f  4
#  155 -6.2541320e+03 1.86e-05 2.00e+10  -1.0 1.31e-01   2.1 5.32e-01 5.49e-02f  1
#  156 -6.2626868e+03 1.82e-05 5.05e+10  -1.0 3.04e-01   1.6 3.51e-01 2.38e-02f  4
#  157 -6.2402750e+03 1.70e-05 2.42e+10  -1.0 1.34e-01   2.0 9.94e-01 1.27e-01h  3
#  158 -6.2749019e+03 1.35e-05 1.15e+10  -1.0 4.67e-02   2.4 6.75e-01 2.42e-01f  1
#  159 -6.2878476e+03 1.27e-05 3.66e+10  -1.0 1.93e-01   2.0 4.71e-01 6.26e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160 -6.2859831e+03 1.25e-05 3.58e+10  -1.0 6.24e-01   1.5 2.51e-01 2.07e-02f  5
#  161 -6.2994912e+03 1.21e-05 8.33e+11  -1.0 3.65e-01   1.9 7.59e-01 4.96e-02f  3
#  162 -5.9237048e+03 2.65e-06 2.11e+11  -1.0 6.22e-02   2.3 1.00e+00 9.14e-01H  1
#  163 -6.1140584e+03 4.71e-06 1.80e+11  -1.0 2.81e-01   1.9 5.57e-01 1.20e-01f  1
#  164 -6.2468910e+03 1.16e-05 1.47e+12  -1.0 7.66e-01   1.4 4.48e-02 8.56e-02f  3
#  165 -6.2531139e+03 1.12e-05 1.30e+12  -1.0 2.46e-01   1.8 4.49e-01 3.52e-02f  2
#  166 -6.2508071e+03 9.81e-06 8.17e+10  -1.0 1.23e-01   2.2 8.61e-01 1.90e-01f  1
#  167 -6.2623995e+03 1.01e-05 3.69e+11  -1.0 1.96e-01   1.8 1.90e-01 8.60e-02f  1
#  168 -6.2774181e+03 9.84e-06 7.05e+10  -1.0 4.33e-01   1.3 2.57e-01 4.33e-03F  1
#  169 -6.2781535e+03 9.82e-06 7.05e+10  -1.0 2.09e-01   1.7 6.79e-01 3.84e-04F  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170 -6.2836086e+03 9.50e-06 6.99e+10  -1.0 8.38e-02   2.1 5.23e-01 7.84e-03F  1
#  171 -6.2840588e+03 9.30e-06 4.70e+09  -1.0 2.06e-01   1.7 4.67e-01 3.18e-02f  5
#  172 -6.2887821e+03 8.92e-06 4.15e+09  -1.0 9.00e-02   2.1 6.39e-01 8.24e-02f  3
#  173 -6.2943891e+03 8.74e-06 9.12e+07  -1.0 3.49e-01   1.6 4.54e-01 2.59e-02f  1
#  174 -6.3004254e+03 8.32e-06 6.90e+07  -2.5 9.81e-02   2.0 2.74e-01 5.55e-02f  3
#  175 -6.3062254e+03 7.58e-06 1.01e+11  -2.5 4.48e-02   2.5 4.81e-01 9.12e-02f  3
#  176 -6.3123695e+03 7.46e-06 9.77e+10  -2.5 1.21e-01   2.0 2.06e-01 2.35e-02f  3
#  177 -6.3151520e+03 7.17e-06 9.36e+10  -2.5 5.47e-02   2.4 4.10e-01 3.95e-02f  4
#  178 -6.3159851e+03 7.04e-06 9.20e+10  -2.5 2.47e-01   1.9 1.47e-01 1.79e-02f  4
#  179 -6.3188971e+03 6.84e-06 8.93e+10  -2.5 6.08e-02   2.4 6.00e-01 2.85e-02f  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180 -6.3208324e+03 6.79e-06 8.88e+10  -2.5 1.60e-01   1.9 1.78e-01 6.67e-03f  5
#  181 -6.3217361e+03 6.68e-06 8.73e+10  -2.5 6.46e-02   2.3 4.57e-01 1.68e-02f  4
#  182 -6.3217360e+03 6.63e-06 8.66e+10  -2.5 1.76e-01   1.8 1.42e-01 6.99e-03f  6
#  183 -6.3227098e+03 6.54e-06 8.54e+10  -2.5 6.94e-02   2.2 1.00e+00 1.40e-02f  5
#  184 -6.1964675e+03 6.03e-06 7.75e+10  -2.5 1.88e-01   1.8 1.23e-01 8.81e-02w  1
#  185 -6.2820097e+03 5.45e-06 6.29e+10  -2.5 1.41e-01   2.2 4.20e-01 1.00e-01w  1
#  186 -6.1140728e+03 1.87e-05 5.52e+11  -2.5 3.83e-01   1.7 1.93e-01 1.63e-01w  1
#  187 -6.3233493e+03 6.51e-06 8.50e+10  -2.5 1.39e-01   2.1 1.23e-01 5.51e-03f  4
#  188 -6.3236892e+03 6.40e-06 8.35e+10  -2.5 3.44e-02   2.6 6.94e-01 1.61e-02f  5
#  189 -6.3243095e+03 6.35e-06 8.27e+10  -2.5 9.16e-02   2.1 2.39e-01 8.78e-03f  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190 -6.3243555e+03 6.24e-06 8.14e+10  -2.5 4.06e-02   2.5 8.16e-01 1.59e-02f  6
#  191 -6.3245830e+03 6.20e-06 8.09e+10  -2.5 9.91e-02   2.0 3.47e-01 6.74e-03f  4
#  192 -6.3248799e+03 6.13e-06 7.99e+10  -2.5 4.22e-02   2.5 5.76e-01 1.17e-02f  6
#  193 -6.3256243e+03 6.11e-06 7.96e+10  -2.5 1.27e-01   2.0 2.89e-01 4.28e-03f  7
#  194 -6.3261861e+03 6.07e-06 7.91e+10  -2.5 4.47e-02   2.4 9.59e-01 5.94e-03f  8
#  195 -6.3265903e+03 6.06e-06 7.89e+10  -2.5 2.06e-01   1.9 2.22e-01 2.11e-03f  5
#  196 -6.3267463e+03 6.03e-06 7.85e+10  -2.5 5.62e-02   2.4 4.96e-01 5.07e-03f  7
#  197 -6.2592471e+03 5.67e-06 6.99e+10  -2.5 1.58e-01   1.9 1.99e-01 6.21e-02w  1
#  198 -6.3017888e+03 5.33e-06 5.25e+10  -2.5 1.03e-01   2.3 9.49e-02 6.02e-02w  1
#  199 -6.2947596e+03 5.11e-06 5.00e+10  -2.5 2.91e-01   1.8 7.45e-01 4.56e-02w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200 -6.3269915e+03 6.02e-06 7.85e+10  -2.5 8.76e-02   2.3 1.99e-01 9.70e-04f  6
#  201 -6.3270477e+03 6.01e-06 7.84e+10  -2.5 1.76e-01   1.8 1.64e-01 1.09e-03f  8
#  202 -6.3272535e+03 6.01e-06 7.83e+10  -2.5 7.29e-02   2.2 1.00e+00 1.12e-03f  9
#  203 -6.3273649e+03 5.98e-06 7.80e+10  -2.5 3.14e-02   2.6 8.95e-01 3.80e-03f  8
#  204 -6.3274660e+03 5.98e-06 7.79e+10  -2.5 8.67e-02   2.2 3.78e-01 1.14e-03f  7
#  205 -6.3275533e+03 5.96e-06 7.77e+10  -2.5 3.36e-02   2.6 5.91e-01 2.58e-03f  7
#  206 -6.3276374e+03 5.96e-06 7.76e+10  -2.5 9.99e-02   2.1 2.72e-01 7.20e-04f 10
#  207 -6.3277100e+03 5.95e-06 7.75e+10  -2.5 4.02e-02   2.5 1.00e+00 1.47e-03f  9
#  208 -6.3277280e+03 5.94e-06 7.75e+10  -2.5 1.12e-01   2.1 2.64e-01 7.12e-04f  8
#  209 -6.3277747e+03 5.94e-06 7.74e+10  -2.5 4.20e-02   2.5 6.28e-01 7.70e-04f  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210 -6.1958348e+03 7.70e-06 6.23e+10  -2.5 2.04e-01   2.0 2.54e-01 1.43e-01w  1
#  211 -6.2732738e+03 7.38e-06 4.82e+10  -2.5 8.43e-02   2.4 4.39e-01 1.39e-01w  1
#  212 -6.2572000e+03 9.90e-06 4.82e+09  -2.5 2.40e-01   2.0 2.33e-01 1.25e-01w  1
#  213 -6.3278146e+03 5.94e-06 7.74e+10  -2.5 7.00e-02   2.4 2.54e-01 2.79e-04f  9
#  214 -6.3278523e+03 5.94e-06 7.74e+10  -2.5 1.36e-01   1.9 3.08e-01 2.02e-04f  9
#  215 -6.3278823e+03 5.93e-06 7.73e+10  -2.5 6.07e-02   2.3 6.45e-01 4.45e-04f 11
#  216 -6.3279100e+03 5.93e-06 7.73e+10  -2.5 1.67e-01   1.9 1.63e-01 1.44e-04f 11
#  217 -6.3279285e+03 5.93e-06 7.73e+10  -2.5 6.65e-02   2.3 5.69e-01 2.88e-04f 11
#  218 -6.3279454e+03 5.93e-06 7.73e+10  -2.5 1.85e-01   1.8 1.96e-01 8.79e-05f 11
#  219 -6.3279558e+03 5.93e-06 7.73e+10  -2.5 7.53e-02   2.2 3.95e-01 1.76e-04f 10
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220 -6.3279667e+03 5.93e-06 7.73e+10  -2.5 1.92e-01   1.8 1.72e-01 8.65e-05f 10
#  221 -6.3279700e+03 5.93e-06 7.73e+10  -2.5 8.34e-02   2.2 3.11e-01 1.26e-04f 12
#  222 -6.3279870e+03 5.93e-06 7.73e+10  -2.5 3.47e-02   2.6 1.00e+00 2.39e-04f 11
#  223 -6.1440172e+03 7.97e-06 4.43e+10  -2.5 1.01e-01   2.1 2.66e-01 3.04e-01w  1
#  224 -6.2279283e+03 6.56e-06 3.31e+10  -2.5 7.75e-02   2.6 1.86e-01 1.83e-01w  1
#  225 -6.2778024e+03 6.30e-06 1.52e+10  -2.5 2.25e-01   2.1 1.00e+00 5.52e-02w  1
#  226 -6.3279967e+03 5.93e-06 7.72e+10  -2.5 8.78e-02   2.5 2.66e-01 1.49e-04f 11
#  227 -6.3280016e+03 5.93e-06 7.72e+10  -2.5 1.21e-01   2.0 4.11e-01 4.24e-05f 13
#  228 -6.3280093e+03 5.93e-06 7.72e+10  -2.5 7.41e-02   2.5 1.00e+00 7.07e-05f 12
#  229 -6.3280130e+03 5.93e-06 7.72e+10  -2.5 1.29e-01   2.0 2.06e-01 2.36e-05f 14
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230 -6.3280153e+03 5.93e-06 7.72e+10  -2.5 5.09e-02   2.4 6.59e-01 4.11e-05f 15
#  231 -6.3280171e+03 5.93e-06 7.72e+10  -2.5 1.48e-01   1.9 2.59e-01 1.78e-05f 14
#  232 -6.3280184e+03 5.93e-06 7.72e+10  -2.5 6.20e-02   2.3 5.86e-01 3.90e-05f 14
#  233 -6.3280206e+03 5.93e-06 7.72e+10  -2.5 1.62e-01   1.9 2.32e-01 1.42e-05f 13
#  234 -6.3280208e+03 5.93e-06 7.72e+10  -2.5 6.22e-02   2.3 3.90e-01 4.24e-05f 14
#  235 -6.3280213e+03 5.93e-06 7.72e+10  -2.5 1.63e-01   1.8 2.97e-01 1.21e-05f 14
#  236 -6.2070773e+03 5.82e-06 6.15e+10  -2.5 1.17e-01   2.2 4.22e-01 2.08e-01w  1
#  237 -6.2886137e+03 8.01e-06 5.06e+10  -2.5 3.46e-01   1.8 2.11e-01 6.78e-02w  1
#  238 -6.0575565e+03 5.47e-06 2.13e+11  -2.5 1.03e-01   2.2 9.46e-02 8.31e-01w  1
#  239 -6.3280217e+03 5.92e-06 7.72e+10  -2.5 7.38e-02   2.6 4.22e-01 5.09e-05f 12
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240 -6.3280247e+03 5.92e-06 7.72e+10  -2.5 1.52e-01   2.1 5.93e-01 2.14e-05f 13
#  241 -6.3280267e+03 5.92e-06 7.72e+10  -2.5 4.30e-02   2.6 4.67e-01 9.46e-05f 14
#  242 -6.3280288e+03 5.92e-06 7.72e+10  -2.5 9.80e-02   2.1 6.19e-01 1.11e-05f 15
#  243 -6.3280303e+03 5.92e-06 7.72e+10  -2.5 3.82e-02   2.5 5.81e-01 2.87e-05f 14
#  244 -6.3280317e+03 5.92e-06 7.72e+10  -2.5 1.12e-01   2.0 2.11e-01 1.06e-05f 15
#  245 -6.3280325e+03 5.92e-06 7.72e+10  -2.5 4.34e-02   2.5 9.26e-01 1.72e-05f 16
#  246 -6.3280335e+03 5.92e-06 7.72e+10  -2.5 1.27e-01   2.0 2.36e-01 4.75e-06f 16
#  247 -6.3280345e+03 5.92e-06 7.72e+10  -2.5 5.25e-02   2.4 6.14e-01 1.21e-05f 16
#  248 -6.3280346e+03 5.92e-06 7.72e+10  -2.5 1.43e-01   1.9 2.14e-01 4.03e-06f 15
#  249 -6.2701736e+03 5.09e-06 6.53e+10  -2.5 5.92e-02   2.4 4.31e-01 1.41e-01w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250 -6.3007033e+03 4.81e-06 5.53e+10  -2.5 3.15e-01   1.9 1.92e-01 5.75e-02w  1
#  251 -6.3151659e+03 3.96e-06 2.84e+08  -2.5 7.95e-02   2.3 2.27e-01 1.79e-01w  1
#  252 -6.3280351e+03 5.92e-06 7.72e+10  -2.5 4.10e-01   1.8 4.31e-01 8.60e-06f 14
#  253 -6.3280353e+03 5.92e-06 7.72e+10  -2.5 6.87e-02   2.3 6.63e-01 1.01e-05f 16
#  254 -6.3280358e+03 5.92e-06 7.72e+10  -2.5 1.91e-01   1.8 2.51e-01 1.46e-06f 16
#  255 -6.3280362e+03 5.92e-06 7.72e+10  -2.5 7.91e-02   2.2 3.28e-01 3.66e-06f 17
#  256 -6.3280364e+03 5.92e-06 7.72e+10  -2.5 1.98e-01   1.7 1.54e-01 1.94e-06f 18
#  257 -6.3280367e+03 5.92e-06 7.72e+10  -2.5 8.64e-02   2.2 1.00e+00 2.91e-06f 17
#  258 -6.3280371e+03 5.92e-06 7.72e+10  -2.5 3.26e-02   2.6 7.11e-01 8.15e-06f 16
#  259 -6.3280373e+03 5.92e-06 7.72e+10  -2.5 9.86e-02   2.1 2.70e-01 2.21e-06f 18
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260 -6.3280375e+03 5.92e-06 7.72e+10  -2.5 4.02e-02   2.5 9.43e-01 4.38e-06f 18
#  261 -6.3280377e+03 5.92e-06 7.72e+10  -2.5 1.12e-01   2.1 2.52e-01 1.80e-06f 18
#  262 -6.2068451e+03 4.89e-06 5.18e+10  -2.5 4.32e-02   2.5 7.43e-01 3.56e-01w  1
#  263 -6.2744775e+03 4.80e-06 4.95e+10  -2.5 1.91e-01   2.0 9.74e-01 4.19e-02w  1
#  264 -6.2993636e+03 4.38e-06 2.62e+08  -2.5 6.98e-02   2.4 1.00e+00 1.22e-01w  1
#  265 -6.3280378e+03 5.92e-06 7.72e+10  -2.5 1.48e-01   2.0 7.43e-01 2.72e-06f 17
#  266 -6.3280379e+03 5.92e-06 7.72e+10  -2.5 5.48e-02   2.4 5.12e-01 2.89e-06f 16
#  267 -6.3280380e+03 5.92e-06 7.72e+10  -2.5 1.50e-01   1.9 1.96e-01 6.16e-07f 19
#  268 -6.3280381e+03 5.92e-06 7.72e+10  -2.5 6.11e-02   2.3 5.21e-01 2.60e-06f 18
#  269 -6.3280382e+03 5.92e-06 7.72e+10  -2.5 1.64e-01   1.9 2.69e-01 3.35e-07f 19
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270 -6.3280383e+03 5.92e-06 7.72e+10  -2.5 6.28e-02   2.3 5.91e-01 7.14e-07f 20
#  271 -6.3280383e+03 5.92e-06 7.72e+10  -2.5 1.80e-01   1.8 2.03e-01 4.39e-07f 18
#  272 -6.3280383e+03 5.92e-06 7.72e+10  -2.5 7.24e-02   2.2 6.60e-01 7.87e-07f 18
#  273 -6.3280384e+03 5.92e-06 7.72e+10  -2.5 1.89e-01   1.8 1.45e-01 3.96e-07f 19
#  274 -6.3280385e+03 5.92e-06 7.72e+10  -2.5 8.21e-02   2.2 4.22e-01 3.73e-07f 21
#  275 -6.1857625e+03 4.12e-06 3.52e+10  -2.5 3.44e-02   2.6 1.00e+00 5.44e-01w  1
#  276 -6.2899025e+03 3.98e-06 2.75e+10  -2.5 1.55e-01   2.1 4.08e-01 1.12e-01w  1
#  277 -6.2087199e+03 5.52e-06 7.28e+10  -2.5 6.10e-02   2.6 4.93e-01 6.50e-01w  1
#  278 -6.3280385e+03 5.92e-06 7.72e+10  -2.5 1.06e-01   2.1 1.00e+00 1.04e-06f 19
#  279 -6.3280385e+03 5.92e-06 7.72e+10  -2.5 4.35e-02   2.5 8.11e-01 1.15e-06f 19
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280 -6.3280385e+03 5.92e-06 7.72e+10  -2.5 1.16e-01   2.0 2.94e-01 2.21e-07f 19
#  281 -6.3280386e+03 5.92e-06 7.72e+10  -2.5 4.78e-02   2.5 6.32e-01 7.44e-07f 19
#  282 -6.3280386e+03 5.92e-06 7.72e+10  -2.5 1.28e-01   2.0 2.86e-01 1.57e-07f 21
#  283 -6.3280386e+03 5.92e-06 7.72e+10  -2.5 5.48e-02   2.4 5.80e-01 3.95e-07f 21
#  284 -6.3280386e+03 5.92e-06 7.72e+10  -2.5 1.54e-01   1.9 1.86e-01 1.37e-07f 19
#  285 -6.3280387e+03 5.92e-06 7.72e+10  -2.5 5.54e-02   2.3 4.16e-01 1.80e-07f 21
#  286 -6.3280387e+03 5.92e-06 7.72e+10  -2.5 1.61e-01   1.9 2.33e-01 9.02e-08f 22
#  287 -6.3280387e+03 5.92e-06 7.72e+10  -2.5 6.93e-02   2.3 8.69e-01 1.81e-07f 22
#  288 -6.1777972e+03 5.57e-06 6.80e+10  -2.5 1.65e-01   1.8 1.79e-01 1.16e-01w  1
#  289 -6.2067381e+03 5.39e-06 6.51e+10  -2.5 1.20e-01   2.2 3.46e-01 3.32e-02w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290 -6.2907415e+03 5.30e-06 2.53e+10  -2.5 3.52e-01   1.8 4.33e-01 5.30e-02w  1
#  291 -6.1777972e+03 5.57e-06 6.80e+10  -2.5 1.03e-01   2.2 1.16e-01 1.16e-01s 18
#  292 -6.2027442e+03 5.21e-06 6.27e+10  -2.5 5.08e-02   2.6 6.52e-02 6.52e-02s 18
#  293 -6.2374887e+03 5.05e-06 6.01e+10  -2.5 1.51e-01   2.1 3.25e-02 3.25e-02s 18
#  294 -6.2710020e+03 4.52e-06 5.10e+10  -2.5 5.70e-02   2.6 1.10e-01 1.10e-01s 18
#  295 -6.2355287e+03 5.28e-06 1.04e+10  -2.5 1.68e-01   2.1 2.15e-01 2.15e-01s 18
#  296 -6.2696539e+03 4.85e-06 9.21e+09  -2.5 3.86e-02   2.5 1.08e-01 1.08e-01s 18
#  297 -6.2730569e+03 5.04e-06 6.36e+09  -2.5 1.11e-01   2.0 7.80e-02 7.80e-02s 18
#  298 -6.2836094e+03 4.52e-06 5.93e+09  -2.5 4.42e-02   2.5 1.03e-01 0.00e+00S 18
#  299 -6.2837276e+03 6.50e-06 3.05e+07  -2.5 1.33e-01   2.0 9.28e-02 1.94e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300 -6.2841695e+03 5.55e-06 8.26e+11  -2.5 1.02e-01   2.4 5.52e-02 1.93e-01f  1
#  301 -6.3076323e+03 5.16e-06 5.83e+11  -2.5 1.65e-01   1.9 1.66e-01 9.04e-02f  2
#  302 -6.3139938e+03 4.89e-06 4.14e+11  -2.5 1.04e-01   2.4 1.00e+00 5.87e-02f  4
#  303 -6.3150534e+03 4.82e-06 4.06e+11  -2.5 1.63e-01   1.9 1.29e-01 1.52e-02f  4
#  304 -6.3189268e+03 4.64e-06 3.89e+11  -2.5 8.37e-02   2.3 4.49e-01 3.94e-02f  4
#  305 -6.3205471e+03 4.60e-06 3.85e+11  -2.5 2.01e-01   1.8 3.44e-01 8.66e-03f  5
#  306 -6.3235371e+03 4.50e-06 3.77e+11  -2.5 7.12e-02   2.3 3.18e-01 2.24e-02f  6
#  307 -6.3246451e+03 4.48e-06 3.75e+11  -2.5 1.64e-01   1.8 2.33e-01 4.06e-03f  6
#  308 -6.3255639e+03 4.45e-06 3.73e+11  -2.5 8.07e-02   2.2 5.43e-01 5.84e-03f  6
#  309 -6.3257159e+03 4.36e-06 3.65e+11  -2.5 4.63e-02   2.6 1.00e+00 2.16e-02f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310 -6.3259164e+03 4.34e-06 3.63e+11  -2.5 8.09e-02   2.2 5.79e-01 5.29e-03f  5
#  311 -6.1952018e+03 3.32e-06 6.94e+10  -2.5 2.92e-02   2.6 5.24e-01 4.59e-01w  1
#  312 -6.2800012e+03 3.12e-06 4.03e+10  -2.5 1.42e-01   2.1 1.69e-01 8.59e-02w  1
#  313 -6.2628077e+03 2.59e-06 1.30e+11  -2.5 4.96e-02   2.5 1.00e+00 3.68e-01w  1
#  314 -6.3263287e+03 4.27e-06 3.57e+11  -2.5 8.95e-02   2.1 5.24e-01 1.44e-02f  5
#  315 -6.3267580e+03 4.23e-06 3.53e+11  -2.5 4.51e-02   2.5 6.52e-01 1.10e-02f  5
#  316 -6.3272270e+03 4.22e-06 3.53e+11  -2.5 1.81e-01   2.0 3.03e-01 1.90e-03f  7
#  317 -6.3275464e+03 4.20e-06 3.51e+11  -2.5 4.49e-02   2.4 6.46e-01 5.73e-03f  7
#  318 -6.3277994e+03 4.19e-06 3.50e+11  -2.5 1.15e-01   2.0 4.31e-01 1.15e-03f  7
#  319 -6.3278185e+03 4.18e-06 3.49e+11  -2.5 5.24e-02   2.4 4.08e-01 3.71e-03f  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320 -6.3281145e+03 4.17e-06 3.49e+11  -2.5 1.50e-01   1.9 3.92e-01 8.19e-04f  7
#  321 -6.3281912e+03 4.16e-06 3.48e+11  -2.5 1.04e-01   2.3 4.19e-01 1.78e-03f  7
#  322 -6.3283046e+03 4.16e-06 3.48e+11  -2.5 1.68e-01   1.9 1.73e-01 5.97e-04f  9
#  323 -6.3284352e+03 4.16e-06 3.47e+11  -2.5 6.82e-02   2.3 7.68e-01 1.10e-03f  8
#  324 -6.2039088e+03 5.05e-06 3.11e+11  -2.5 1.75e-01   1.8 1.66e-01 9.24e-02w  1
#  325 -6.3039705e+03 4.89e-06 1.02e+11  -2.5 1.52e-01   2.2 2.36e-01 1.43e-01w  1
#  326 -5.4729563e+03 8.15e-05 6.24e+09  -2.5 2.90e-01   1.8 1.68e-01 5.85e-01w  1
#  327 -6.3285392e+03 4.16e-06 3.47e+11  -2.5 1.87e-01   2.2 1.66e-01 3.61e-04f  8
#  328 -6.3285815e+03 4.15e-06 3.47e+11  -2.5 3.35e-02   2.6 6.43e-01 1.30e-03f 10
#  329 -6.3286255e+03 4.15e-06 3.47e+11  -2.5 9.12e-02   2.1 3.44e-01 3.62e-04f 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330 -6.3286293e+03 4.14e-06 3.46e+11  -2.5 3.48e-02   2.6 1.00e+00 1.06e-03f 10
#  331 -6.3286677e+03 4.14e-06 3.46e+11  -2.5 1.05e-01   2.1 3.93e-01 2.66e-04f  8
#  332 -6.3286978e+03 4.14e-06 3.46e+11  -2.5 4.12e-02   2.5 4.81e-01 7.16e-04f 10
#  333 -6.3287248e+03 4.14e-06 3.46e+11  -2.5 2.07e-01   2.0 3.67e-01 1.64e-04f 11
#  334 -6.3287316e+03 4.14e-06 3.46e+11  -2.5 4.39e-02   2.5 5.09e-01 5.98e-04f  9
#  335 -6.3287394e+03 4.14e-06 3.46e+11  -2.5 1.48e-01   2.0 2.32e-01 1.56e-04f 11
#  336 -6.3287633e+03 4.13e-06 3.46e+11  -2.5 5.18e-02   2.4 6.26e-01 4.39e-04f 10
#  337 -6.2071702e+03 5.16e-06 3.03e+11  -2.5 1.33e-01   1.9 2.44e-01 1.21e-01w  1
#  338 -6.2981541e+03 4.78e-06 4.92e+10  -2.5 1.09e-01   2.3 2.48e-01 1.75e-01w  1
#  339 -6.1565512e+03 8.14e-06 6.04e+11  -2.5 2.45e-01   1.9 1.00e+00 1.92e-01w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340 -6.3287763e+03 4.13e-06 3.45e+11  -2.5 6.34e-02   2.3 2.44e-01 1.18e-04f 10
#  341 -6.3287943e+03 4.13e-06 3.45e+11  -2.5 1.69e-01   1.8 2.18e-01 9.77e-05f 14
#  342 -6.3288135e+03 4.13e-06 3.45e+11  -2.5 7.16e-02   2.2 1.00e+00 1.76e-04f 12
#  343 -6.3288246e+03 4.13e-06 3.45e+11  -2.5 3.35e-01   1.8 1.68e-01 4.92e-05f 11
#  344 -6.3288271e+03 4.13e-06 3.45e+11  -2.5 8.32e-02   2.2 3.09e-01 1.03e-04f 12
#  345 -6.3288355e+03 4.13e-06 3.45e+11  -2.5 3.20e-02   2.6 9.46e-01 2.44e-04f 13
#  346 -6.3288451e+03 4.13e-06 3.45e+11  -2.5 8.91e-02   2.1 3.36e-01 6.46e-05f 13
#  347 -6.3288515e+03 4.13e-06 3.45e+11  -2.5 3.45e-02   2.6 7.54e-01 1.42e-04f 10
#  348 -6.3288532e+03 4.13e-06 3.45e+11  -2.5 1.04e-01   2.1 2.91e-01 4.50e-05f 13
#  349 -6.3288568e+03 4.13e-06 3.45e+11  -2.5 3.78e-02   2.5 6.84e-01 9.35e-05f 13
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350 -6.2041788e+03 4.34e-06 2.78e+11  -2.5 1.14e-01   2.0 2.94e-01 1.56e-01w  1
#  351 -6.2970255e+03 3.47e-06 2.26e+10  -2.5 7.75e-02   2.5 2.89e-01 2.26e-01w  1
#  352 -5.9087735e+03 1.89e-05 2.46e+11  -2.5 2.10e-01   2.0 3.40e-01 4.56e-01w  1
#  353 -6.3288608e+03 4.13e-06 3.45e+11  -2.5 5.88e-02   2.4 2.94e-01 3.81e-05f 12
#  354 -6.3288610e+03 4.13e-06 3.45e+11  -2.5 1.38e-01   1.9 2.37e-01 2.54e-05f 12
#  355 -6.3288628e+03 4.13e-06 3.45e+11  -2.5 5.77e-02   2.4 1.00e+00 7.45e-05f 13
#  356 -6.3288656e+03 4.13e-06 3.45e+11  -2.5 1.41e-01   1.9 2.45e-01 1.76e-05f 13
#  357 -6.3288690e+03 4.13e-06 3.45e+11  -2.5 6.11e-02   2.3 5.83e-01 3.90e-05f 14
#  358 -6.3288713e+03 4.13e-06 3.45e+11  -2.5 2.99e-01   1.8 1.74e-01 1.77e-05f 14
#  359 -6.3288732e+03 4.13e-06 3.45e+11  -2.5 7.06e-02   2.3 5.49e-01 2.24e-05f 13
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360 -6.3288756e+03 4.13e-06 3.45e+11  -2.5 1.81e-01   1.8 1.48e-01 6.72e-06f 15
#  361 -6.3288770e+03 4.13e-06 3.45e+11  -2.5 7.42e-02   2.2 5.15e-01 1.35e-05f 17
#  362 -6.3288771e+03 4.13e-06 3.45e+11  -2.5 3.18e-02   2.6 1.00e+00 3.10e-05f 15
#  363 -6.2670534e+03 3.82e-06 1.74e+11  -2.5 9.23e-02   2.2 3.09e-01 1.00e-01w  1
#  364 -6.3092169e+03 3.21e-06 2.73e+11  -2.5 6.43e-02   2.6 1.80e-01 2.06e-01w  1
#  365 -6.2808032e+03 2.82e-06 1.40e+09  -2.5 1.25e-01   2.1 1.59e-01 1.80e-01w  1
#  366 -6.3288785e+03 4.13e-06 3.45e+11  -2.5 9.06e-02   2.5 3.09e-01 1.23e-05f 13
#  367 -6.3288787e+03 4.13e-06 3.45e+11  -2.5 1.09e-01   2.1 2.33e-01 1.03e-05f 16
#  368 -6.3288799e+03 4.13e-06 3.45e+11  -2.5 4.28e-02   2.5 5.22e-01 1.53e-05f 16
#  369 -6.3288806e+03 4.13e-06 3.45e+11  -2.5 1.21e-01   2.0 3.02e-01 5.49e-06f 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370 -6.3288811e+03 4.13e-06 3.45e+11  -2.5 4.99e-02   2.4 5.87e-01 8.81e-06f 15
#  371 -6.3288813e+03 4.13e-06 3.45e+11  -2.5 1.32e-01   2.0 2.27e-01 4.17e-06f 16
#  372 -6.3288819e+03 4.13e-06 3.45e+11  -2.5 5.46e-02   2.4 5.09e-01 5.95e-06f 17
#  373 -6.3288819e+03 4.13e-06 3.45e+11  -2.5 1.42e-01   1.9 2.58e-01 3.51e-06f 17
#  374 -6.3288820e+03 4.13e-06 3.45e+11  -2.5 6.14e-02   2.3 1.00e+00 7.22e-06f 15
#  375 -6.3288826e+03 4.13e-06 3.45e+11  -2.5 1.50e-01   1.9 1.73e-01 2.64e-06f 16
#  376 -6.1715586e+03 4.97e-06 2.26e+11  -2.5 6.66e-02   2.3 4.61e-01 2.87e-01w  1
#  377 -6.2882744e+03 5.37e-06 1.91e+11  -2.5 2.53e-01   1.8 2.77e-01 7.45e-02w  1
#  378 -5.9805920e+03 2.51e-05 1.98e+12  -2.5 7.65e-02   2.2 1.50e-01 9.00e-01w  1
#  379 -6.3288828e+03 4.13e-06 3.45e+11  -2.5 5.61e-02   2.7 4.61e-01 4.38e-06f 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380 -6.3288833e+03 4.13e-06 3.45e+11  -2.5 8.69e-02   2.2 4.71e-01 3.16e-06f 19
#  381 -6.3288834e+03 4.13e-06 3.45e+11  -2.5 3.25e-02   2.6 1.00e+00 9.21e-06f 15
#  382 -6.3288835e+03 4.13e-06 3.45e+11  -2.5 9.62e-02   2.1 4.57e-01 1.63e-06f 17
#  383 -6.3288836e+03 4.13e-06 3.45e+11  -2.5 3.80e-02   2.6 5.25e-01 5.28e-06f 18
#  384 -6.3288837e+03 4.13e-06 3.45e+11  -2.5 1.03e-01   2.1 3.68e-01 2.65e-06f 17
#  385 -6.3288840e+03 4.13e-06 3.45e+11  -2.5 3.87e-02   2.5 6.96e-01 2.84e-06f 17
#  386 -6.3288842e+03 4.13e-06 3.45e+11  -2.5 1.21e-01   2.0 2.28e-01 9.74e-07f 16
#  387 -6.3288842e+03 4.13e-06 3.45e+11  -2.5 4.83e-02   2.4 7.36e-01 2.78e-06f 19
#  388 -6.3288843e+03 4.13e-06 3.45e+11  -2.5 1.18e-01   2.0 2.55e-01 7.49e-07f 17
#  389 -6.3261950e+03 4.10e-06 3.43e+11  -2.5 5.46e-02   2.4 4.23e-01 6.91e-03w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390 -6.2857370e+03 3.99e-06 3.17e+11  -2.5 2.39e-01   1.9 2.62e-01 3.80e-02w  1
#  391 -6.2758177e+03 3.42e-06 1.44e+11  -2.5 5.85e-02   2.3 3.02e-01 2.27e-01w  1
#  392 -6.3288844e+03 4.13e-06 3.45e+11  -2.5 2.59e-01   1.9 4.23e-01 1.69e-06f 12
#  393 -6.3288845e+03 4.13e-06 3.45e+11  -2.5 6.62e-02   2.3 6.71e-01 2.00e-06f 19
#  394 -6.3288845e+03 4.13e-06 3.45e+11  -2.5 1.71e-01   1.8 1.98e-01 3.57e-07f 19
#  395 -6.3288846e+03 4.13e-06 3.45e+11  -2.5 7.35e-02   2.2 4.35e-01 7.69e-07f 18
#  396 -6.3288847e+03 4.13e-06 3.45e+11  -2.5 1.83e-01   1.8 1.48e-01 3.91e-07f 18
#  397 -6.3288847e+03 4.13e-06 3.45e+11  -2.5 8.39e-02   2.2 3.16e-01 5.78e-07f 20
#  398 -6.3288848e+03 4.13e-06 3.45e+11  -2.5 3.02e-02   2.6 1.00e+00 1.11e-06f 19
#  399 -6.3288848e+03 4.13e-06 3.45e+11  -2.5 9.26e-02   2.1 3.07e-01 4.68e-07f 21
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400 -6.3288848e+03 4.13e-06 3.45e+11  -2.5 3.64e-02   2.6 1.00e+00 7.33e-07f 20
#  401 -6.3288849e+03 4.13e-06 3.45e+11  -2.5 1.06e-01   2.1 2.85e-01 2.77e-07f 21
#  402 -6.2749672e+03 3.39e-06 1.68e+11  -2.5 4.15e-02   2.5 7.62e-01 1.91e-01w  1
#  403 -6.2807612e+03 3.38e-06 1.67e+11  -2.5 2.01e-01   2.0 9.89e-02 4.35e-03w  1
#  404 -6.3131491e+03 3.15e-06 1.26e+11  -2.5 8.34e-02   2.5 3.45e-01 7.86e-02w  1
#  405 -6.2749672e+03 3.39e-06 1.68e+11  -2.5 2.21e-01   2.0 1.91e-01 1.91e-01S 19
#  406 -6.2809385e+03 3.01e-06 5.21e+11  -2.5 8.66e-02   2.4 2.28e-01 2.43e-01f  1
#  407 -6.3045650e+03 1.04e-05 2.80e+09  -2.5 1.41e-01   1.9 6.09e-02 9.06e-02F  1
#  408 -6.3046795e+03 1.35e-10 4.08e+14  -2.5 9.83e-04   6.0 1.00e+00 1.00e+00f  1
#  409 -6.3046795e+03 2.08e-11 2.12e+09  -2.5 3.21e-07  15.8 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410 -6.3046795e+03 1.93e-11 2.80e+05  -2.5 4.11e-11  15.3 1.00e+00 1.00e+00f  1
#  411 -6.3046795e+03 2.13e-11 1.54e+04  -3.8 2.10e-11  14.9 1.00e+00 1.00e+00h  1
#  412 -6.3046795e+03 2.34e-11 5.14e+03  -5.7 2.10e-11  14.4 1.00e+00 1.00e+00h  1
#  413 -6.3046795e+03 2.13e-11 1.18e+03  -5.7 1.45e-11  13.9 1.00e+00 1.00e+00h  1
#  414 -6.3046795e+03 2.34e-11 5.73e+02  -5.7 2.10e-11  13.4 1.00e+00 1.00e+00h  1
#  415 -6.3046795e+03 2.09e-11 1.91e+02  -5.7 2.10e-11  13.0 1.00e+00 1.00e+00h  1
#  416 -6.3046795e+03 2.34e-11 9.19e+01  -5.7 3.04e-11  12.5 1.00e+00 1.00e+00h  1
#  417 -6.3046795e+03 2.09e-11 9.08e+01  -5.7 9.01e-11  12.0 1.00e+00 1.00e+00h  1
#  418 -6.3046795e+03 2.33e-11 1.23e+02  -5.7 2.63e-10  11.5 1.00e+00 1.00e+00h  1
#  419 -6.3046795e+03 2.29e-11 8.17e+01  -5.7 7.29e-10  11.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420 -6.3046795e+03 2.84e-11 2.62e+02  -5.7 1.81e-09  10.6 1.00e+00 1.00e+00h  1
#  421 -6.3046795e+03 2.95e-11 3.12e+02  -5.7 3.80e-09  10.1 1.00e+00 1.00e+00h  1
#  422 -6.3046795e+03 2.57e-11 8.78e+02  -5.7 6.94e-09   9.6 1.00e+00 1.00e+00f  1
#  423 -6.3046796e+03 2.36e-11 1.17e+03  -5.7 1.68e-08   9.1 1.00e+00 1.00e+00f  1
#  424 -6.3046799e+03 2.58e-11 1.44e+03  -5.7 5.06e-08   8.7 1.00e+00 1.00e+00f  1
#  425 -6.3046808e+03 2.34e-11 1.08e+03  -5.7 1.52e-07   8.2 1.00e+00 1.00e+00f  1
#  426 -6.3046836e+03 2.59e-11 5.11e+02  -5.7 4.56e-07   7.7 1.00e+00 1.00e+00f  1
#  427 -6.3046918e+03 2.53e-11 8.64e+01  -5.7 1.37e-06   7.2 1.00e+00 1.00e+00f  1
#  428 -6.3047162e+03 2.93e-11 1.94e+02  -5.7 4.10e-06   6.8 1.00e+00 1.00e+00f  1
#  429 -6.3047886e+03 2.25e-11 1.95e+02  -5.7 1.24e-05   6.3 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430 -6.3050054e+03 2.75e-11 1.94e+02  -5.7 3.69e-05   5.8 1.00e+00 1.00e+00f  1
#  431 -6.3056171e+03 3.48e-11 1.96e+02  -5.7 1.14e-04   5.3 1.00e+00 1.00e+00f  1
#  432 -6.3062351e+03 5.94e-11 1.96e+02  -5.7 3.14e-04   4.8 1.00e+00 3.40e-01f  1
#  433 -6.3063129e+03 5.91e-11 1.93e+02  -5.7 9.32e-04   4.4 1.00e+00 1.31e-02f  1
#  434 -6.3070235e+03 1.12e-10 1.96e+02  -5.7 2.78e-03   3.9 1.00e+00 4.70e-02f  1
#  435 -6.3076838e+03 1.58e-10 1.96e+02  -5.7 7.54e-03   3.4 1.00e+00 1.44e-02f  1
#  436 -6.3097120e+03 7.87e-09 1.99e+02  -5.7 2.46e-02   2.9 1.00e+00 6.22e-02f  1
#  437 -6.3110632e+03 8.12e-09 1.99e+02  -5.7 4.22e-02   2.5 2.75e-01 1.38e-02f  5
#  438 -6.3119813e+03 8.35e-09 1.98e+02  -5.7 1.34e-01   2.0 2.77e-01 4.18e-03f  6
#  439 -6.3128040e+03 8.68e-09 3.38e+02  -5.7 4.63e-02   2.4 1.00e+00 1.36e-02f  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440 -6.3134001e+03 9.06e-09 3.29e+02  -5.7 1.44e-01   1.9 1.42e-01 2.26e-03f  6
#  441 -6.3134615e+03 1.06e-08 2.92e+02  -5.7 6.38e-02   2.4 8.76e-01 8.54e-03f  6
#  442 -6.3138438e+03 1.06e-08 2.92e+02  -5.7 1.33e-01   1.9 1.18e-01 3.90e-04f  1
#  443 -6.3141516e+03 1.07e-08 2.89e+02  -5.7 6.58e-02   2.3 3.52e-02 7.24e-03f  5
#  444 -6.3141532e+03 1.07e-08 2.89e+02  -5.7 2.36e-01   1.8 9.59e-02 1.32e-06f  1
#  445 -6.3147858e+03 1.09e-08 2.86e+02  -5.7 6.61e-02   2.3 1.00e+00 7.03e-03f  4
#  446 -6.3150716e+03 1.14e-08 2.84e+02  -5.7 2.19e-01   1.8 9.75e-02 3.00e-03f  8
#  447 -6.3155078e+03 1.28e-08 2.78e+02  -5.7 8.09e-02   2.2 1.00e+00 5.80e-03f  6
#  448 -6.3163537e+03 1.29e-08 1.94e+02  -5.7 2.92e-02   2.6 6.42e-01 1.62e-02f  3
#  449 -6.3166578e+03 1.31e-08 1.93e+02  -5.7 8.31e-02   2.2 1.83e-01 6.09e-03f  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450 -6.3173047e+03 1.33e-08 1.90e+02  -5.7 4.13e-02   2.6 9.23e-01 8.17e-03f  7
#  451 -6.3175836e+03 1.54e-08 1.92e+02  -5.7 9.83e-02   2.1 4.62e-04 5.63e-03f  6
#  452 -6.3176388e+03 1.54e-08 1.92e+02  -5.7 3.95e-02   2.5 1.00e+00 1.64e-04f  1
#  453 -6.3180867e+03 1.54e-08 1.93e+02  -5.7 1.12e-01   2.1 4.82e-01 1.78e-03f  1
#  454 -6.3184380e+03 1.54e-08 1.91e+02  -5.7 4.61e-02   2.5 2.66e-01 8.37e-03f  5
#  455 -6.3187993e+03 1.55e-08 1.90e+02  -5.7 1.23e-01   2.0 2.62e-01 1.97e-03f  7
#  456 -6.3190494e+03 1.56e-08 1.91e+02  -5.7 5.71e-02   2.4 6.26e-01 9.67e-03f  3
#  457 -6.3193628e+03 1.56e-08 1.95e+02  -5.7 1.62e-01   1.9 1.43e-01 1.57e-03f  7
#  458 -6.3194851e+03 1.68e-08 1.91e+02  -5.7 5.01e-02   2.4 6.16e-01 7.54e-03f  6
#  459 -6.3195989e+03 1.70e-08 1.96e+02  -5.7 1.50e-01   1.9 1.47e-01 3.02e-03f  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  460 -6.3200933e+03 1.73e-08 1.94e+02  -5.7 7.05e-02   2.3 6.18e-01 8.89e-03f  4
#  461 -6.3203827e+03 1.89e-08 1.90e+02  -5.7 1.47e-01   1.8 1.39e-01 3.06e-03f  4
#  462 -6.3210517e+03 1.93e-08 1.94e+02  -5.7 6.77e-02   2.3 1.23e-01 7.49e-03f  3
#  463 -6.3215459e+03 1.94e-08 1.93e+02  -5.7 2.35e-01   1.8 3.88e-02 1.94e-03f  3
#  464 -6.3152980e+03 4.19e-08 1.94e+02  -5.7 6.65e-02   2.2 4.94e-01 2.33e-02w  1
#  465 -6.3199604e+03 4.14e-08 5.92e+02  -5.7 3.63e-02   2.6 2.89e-04 1.53e-02w  1
#  466 -6.3192387e+03 5.10e-08 2.07e+07  -5.7 1.05e-01   2.2 1.00e+00 2.25e-02w  1
#  467 -6.3219965e+03 2.03e-08 1.89e+02  -5.7 4.09e-02   2.6 4.94e-01 5.82e-03f  2
#  468 -6.3222156e+03 2.03e-08 1.94e+02  -5.7 9.85e-02   2.1 7.37e-02 4.67e-03f  5
#  469 -6.3227938e+03 2.04e-08 1.92e+02  -5.7 3.66e-02   2.5 5.59e-01 7.95e-03f  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  470 -6.3234139e+03 2.21e-08 1.92e+02  -5.7 1.70e-01   2.1 2.24e-01 4.13e-03f  2
#  471 -6.3236359e+03 2.21e-08 1.88e+02  -5.7 4.23e-02   2.5 6.40e-01 4.00e-03f  6
#  472 -6.3238468e+03 2.21e-08 1.85e+02  -5.7 1.14e-01   2.0 2.43e-01 1.56e-03f  8
#  473 -6.3238768e+03 2.22e-08 1.92e+02  -5.7 4.12e-02   2.4 7.09e-01 5.90e-03f  6
#  474 -6.3243151e+03 2.22e-08 1.92e+02  -5.7 1.32e-01   2.0 2.56e-01 5.28e-04f  1
#  475 -6.3244180e+03 2.22e-08 1.87e+02  -5.7 5.40e-02   2.4 3.21e-01 1.58e-03f  6
#  476 -6.3244458e+03 2.28e-08 1.92e+02  -5.7 2.31e-01   1.9 2.18e-01 1.33e-03f  7
#  477 -6.3246144e+03 2.27e-08 1.84e+02  -5.7 5.94e-02   2.3 3.19e-01 3.93e-03f  6
#  478 -6.3247959e+03 2.28e-08 1.87e+02  -5.7 1.44e-01   1.9 6.15e-02 1.33e-03f  2
#  479 -6.3251043e+03 2.28e-08 1.87e+02  -5.7 5.64e-02   2.3 8.27e-01 2.58e-03f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  480 -6.3253252e+03 2.37e-08 1.91e+02  -5.7 2.87e-01   1.8 1.30e-01 1.29e-03f  6
#  481 -6.3255254e+03 2.37e-08 1.86e+02  -5.7 7.37e-02   2.2 9.51e-01 1.60e-03f  7
#  482 -6.3256829e+03 2.36e-08 1.86e+02  -5.7 2.69e-02   2.7 4.67e-01 3.11e-03f  8
#  483 -6.3258091e+03 2.36e-08 1.96e+02  -5.7 8.54e-02   2.2 3.74e-01 1.24e-03f  7
#  484 -6.3259230e+03 2.36e-08 1.87e+02  -5.7 3.24e-02   2.6 1.00e+00 3.18e-03f  8
#  485 -6.1458141e+03 4.75e-06 1.95e+02  -5.7 8.96e-02   2.1 2.55e-01 2.67e-01w  1
#  486 -6.1518273e+03 4.69e-06 1.93e+02  -5.7 4.95e-02   2.6 2.27e-01 1.26e-02w  1
#  487 -6.2482865e+03 4.47e-06 1.08e+06  -5.7 1.50e-01   2.1 1.00e+00 7.09e-02w  1
#  488 -6.3260062e+03 2.35e-08 1.96e+02  -5.7 5.57e-02   2.5 2.55e-01 1.04e-03f  8
#  489 -6.3260334e+03 2.35e-08 1.96e+02  -5.7 1.19e-01   2.0 1.59e-01 1.04e-03f  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  490 -6.3260602e+03 2.35e-08 1.96e+02  -5.7 5.56e-02   2.5 8.49e-01 8.12e-05f  1
#  491 -6.3261213e+03 2.35e-08 1.96e+02  -5.7 1.07e-01   2.0 2.02e-01 5.69e-04f  2
#  492 -6.3261331e+03 2.37e-08 1.96e+02  -5.7 7.91e-02   2.4 6.85e-01 2.19e-03f  8
#  493 -6.3262177e+03 2.37e-08 1.96e+02  -5.7 1.20e-01   1.9 1.75e-01 6.41e-04f  6
#  494 -6.3263010e+03 2.37e-08 1.96e+02  -5.7 5.91e-02   2.4 5.44e-01 1.37e-03f  9
#  495 -6.3263979e+03 2.37e-08 1.96e+02  -5.7 1.68e-01   1.9 1.43e-01 7.68e-04f  7
#  496 -6.3264812e+03 2.37e-08 1.96e+02  -5.7 8.98e-02   2.3 1.96e-01 6.38e-04f  1
#  497 -6.3265530e+03 2.37e-08 1.96e+02  -5.7 1.58e-01   1.8 4.91e-02 2.45e-04f  2
#  498 -6.3265667e+03 2.37e-08 1.96e+02  -5.7 7.28e-02   2.3 2.49e-01 4.18e-04f  3
#  499 -6.3265690e+03 2.37e-08 1.96e+02  -5.7 4.33e-01   1.8 1.89e-01 2.89e-04f  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  500 -6.3266043e+03 2.37e-08 1.96e+02  -5.7 7.48e-02   2.2 4.27e-01 4.14e-04f 10
#  501 -6.3266430e+03 2.37e-08 1.96e+02  -5.7 3.12e-02   2.6 5.21e-01 1.65e-03f  8
#  502 -6.3266550e+03 2.37e-08 1.96e+02  -5.7 1.08e-01   2.2 3.88e-01 2.20e-05f  1
#  503 -6.3266659e+03 2.36e-08 1.96e+02  -5.7 3.35e-02   2.6 9.85e-01 1.10e-03f 10
#  504 -6.3266917e+03 2.36e-08 1.96e+02  -5.7 1.49e-01   2.1 3.93e-01 3.57e-04f  2
#  505 -6.3267375e+03 2.36e-08 1.95e+02  -5.7 5.91e-02   2.5 5.77e-03 1.33e-03f  4
#  506 -6.3267856e+03 2.36e-08 1.95e+02  -5.7 9.54e-02   2.1 9.83e-02 1.56e-04f  6
#  507 -6.3267977e+03 2.36e-08 1.96e+02  -5.7 5.01e-02   2.5 3.49e-01 3.16e-04f  3
#  508 -6.3268152e+03 2.36e-08 1.86e+02  -5.7 1.17e-01   2.0 3.31e-01 9.91e-05f  9
#  509 -6.3268324e+03 2.36e-08 1.96e+02  -5.7 5.06e-02   2.4 3.01e-01 3.01e-04f 10
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  510 -6.3268442e+03 2.36e-08 1.95e+02  -5.7 1.65e-01   1.9 1.65e-01 7.22e-05f  3
#  511 -6.3268494e+03 2.36e-08 1.96e+02  -5.7 5.63e-02   2.4 8.80e-03 2.31e-04f 12
#  512 -6.3268591e+03 2.36e-08 1.96e+02  -5.7 1.46e-01   1.9 3.31e-01 1.00e-04f 11
#  513 -6.3267084e+03 2.36e-08 1.96e+02  -5.7 6.07e-02   2.3 6.22e-01 7.90e-04w  1
#  514 -6.2625140e+03 4.77e-07 4.94e+02  -5.7 1.69e-01   1.8 1.67e-02 4.58e-02w  1
#  515 -6.2239880e+03 3.81e-06 5.86e+06  -5.7 8.00e-02   2.3 1.00e+00 2.90e-01w  1
#  516 -6.3268711e+03 2.36e-08 1.89e+02  -5.7 1.89e-01   1.8 6.22e-01 1.97e-04f  2
#  517 -6.3268830e+03 2.36e-08 1.96e+02  -5.7 7.96e-02   2.2 5.56e-01 2.50e-04f  7
#  518 -6.3268974e+03 2.36e-08 1.95e+02  -5.7 2.81e-02   2.6 5.56e-01 2.46e-04f 12
#  519 -6.3269048e+03 2.36e-08 1.96e+02  -5.7 7.85e-02   2.2 3.98e-01 8.90e-05f 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  520 -6.3269115e+03 2.36e-08 1.96e+02  -5.7 3.44e-02   2.6 7.04e-01 2.86e-04f 11
#  521 -6.3269158e+03 2.36e-08 1.95e+02  -5.7 8.73e-02   2.1 3.55e-01 8.19e-05f  9
#  522 -6.3269195e+03 2.36e-08 1.95e+02  -5.7 3.58e-02   2.5 4.90e-01 2.98e-04f  3
#  523 -6.3269283e+03 2.36e-08 1.96e+02  -5.7 1.06e-01   2.1 2.77e-01 6.18e-05f 13
#  524 -6.3269331e+03 2.36e-08 1.96e+02  -5.7 7.16e-02   2.5 8.06e-01 1.75e-04f 11
#  525 -6.3269430e+03 2.36e-08 1.95e+02  -5.7 1.25e-01   2.0 9.89e-02 5.40e-05f 12
#  526 -6.2222107e+03 1.82e-06 1.95e+02  -5.7 4.75e-02   2.4 1.75e-01 3.18e-01w  1
#  527 -6.2222188e+03 1.82e-06 1.95e+02  -5.7 2.23e-01   2.0 3.21e-01 4.64e-06w  1
#  528 -6.2444250e+03 1.79e-06 7.49e+05  -5.7 9.43e-02   2.4 1.00e+00 3.24e-02w  1
#  529 -6.3269490e+03 2.36e-08 1.83e+02  -5.7 2.41e-01   1.9 1.75e-01 1.55e-04f 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  530 -6.3269504e+03 2.36e-08 1.83e+02  -5.7 5.42e-02   2.3 6.07e-01 3.68e-06f  1
#  531 -6.3269522e+03 2.36e-08 1.96e+02  -5.7 1.49e-01   1.9 2.66e-01 3.19e-05f 14
#  532 -6.3269566e+03 2.36e-08 1.96e+02  -5.7 6.73e-02   2.3 1.00e+00 5.82e-05f 13
#  533 -6.3269575e+03 2.36e-08 1.94e+02  -5.7 2.13e-01   1.8 1.29e-01 4.20e-05f 11
#  534 -6.3269620e+03 2.36e-08 1.95e+02  -5.7 1.05e-01   2.2 6.22e-02 4.30e-05f 11
#  535 -6.3269650e+03 2.36e-08 1.96e+02  -5.7 2.76e-02   2.7 4.26e-01 1.11e-04f  5
#  536 -6.3269660e+03 2.36e-08 1.90e+02  -5.7 8.55e-02   2.2 2.56e-01 4.97e-05f 10
#  537 -6.3269687e+03 2.36e-08 1.95e+02  -5.7 5.04e-01   2.6 2.71e-01 1.25e-04f  1
#  538 -6.3269715e+03 2.36e-08 1.96e+02  -5.7 8.72e-02   2.1 4.00e-01 6.23e-05f  7
#  539 -6.3269746e+03 2.36e-08 1.96e+02  -5.7 3.55e-02   2.6 1.39e-01 5.06e-05f 13
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  540 -6.3269780e+03 2.36e-08 1.95e+02  -5.7 9.10e-02   2.1 3.21e-01 2.08e-05f  5
#  541 -6.3269799e+03 2.36e-08 1.96e+02  -5.7 6.58e-02   2.5 6.13e-01 7.88e-05f  9
#  542 -6.3269825e+03 2.36e-08 1.96e+02  -5.7 1.48e-01   2.0 4.07e-01 1.63e-05f 13
#  543 -6.3269836e+03 2.36e-08 1.96e+02  -5.7 4.32e-02   2.5 3.61e-01 6.44e-05f 13
#  544 -6.3269870e+03 2.36e-08 1.95e+02  -5.7 1.20e-01   2.0 3.10e-01 1.18e-05f 14
#  545 -6.3269885e+03 2.36e-08 1.96e+02  -5.7 5.24e-02   2.4 3.85e-01 2.52e-05f 14
#  546 -6.3269897e+03 2.36e-08 1.96e+02  -5.7 1.33e-01   1.9 3.26e-01 6.62e-06f 14
#  547 -6.3269905e+03 2.36e-08 1.95e+02  -5.7 9.42e-02   2.4 3.23e-01 2.25e-05f 14
#  548 -6.1998124e+03 1.99e-06 1.95e+02  -5.7 1.58e-01   1.9 1.64e-01 1.04e-01w  1
#  549 -6.2084165e+03 1.97e-06 1.93e+02  -5.7 8.83e-02   2.3 2.40e-01 9.87e-03w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  550 -6.2818739e+03 2.16e-06 1.61e+07  -5.7 2.67e-01   1.8 4.47e-02 3.68e-02w  1
#  551 -6.3269915e+03 2.36e-08 1.95e+02  -5.7 8.57e-02   2.3 1.64e-01 6.32e-06f 14
#  552 -6.3269915e+03 2.36e-08 1.96e+02  -5.7 1.89e-01   1.8 1.65e-01 7.06e-06f 15
#  553 -6.3269929e+03 2.36e-08 1.82e+02  -5.7 8.21e-02   2.2 5.23e-01 1.16e-05f 14
#  554 -6.3269936e+03 2.36e-08 1.96e+02  -5.7 2.84e-02   2.6 7.26e-01 3.88e-05f 15
#  555 -6.3269940e+03 2.36e-08 1.96e+02  -5.7 8.64e-02   2.2 3.78e-01 9.44e-06f 15
#  556 -6.3269950e+03 2.36e-08 1.96e+02  -5.7 5.46e-02   2.6 6.53e-01 1.99e-05f 13
#  557 -6.3269962e+03 2.36e-08 1.96e+02  -5.7 1.16e-01   2.1 2.08e-01 1.17e-05f 15
#  558 -6.3269969e+03 2.36e-08 1.95e+02  -5.7 3.90e-02   2.5 7.21e-01 1.07e-05f 16
#  559 -6.3269974e+03 2.36e-08 1.96e+02  -5.7 1.08e-01   2.1 2.17e-01 2.35e-06f 12
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  560 -6.3269977e+03 2.36e-08 1.86e+02  -5.7 4.66e-02   2.5 3.83e-01 5.32e-06f  9
#  561 -6.2139868e+03 2.70e-06 1.95e+02  -5.7 1.28e-01   2.0 2.40e-01 1.46e-01w  1
#  562 -6.2145246e+03 2.70e-06 1.95e+02  -5.7 1.04e-01   2.4 1.86e-01 8.83e-04w  1
#  563 -6.2908947e+03 2.91e-06 2.28e+07  -5.7 2.48e-01   1.9 9.61e-01 5.27e-02w  1
#  564 -6.3269979e+03 2.36e-08 1.95e+02  -5.7 8.45e-02   2.4 2.40e-01 2.24e-06f 16
#  565 -6.3269981e+03 2.36e-08 1.96e+02  -5.7 1.49e-01   1.9 1.67e-01 2.26e-06f 17
#  566 -6.3269984e+03 2.36e-08 1.96e+02  -5.7 9.25e-02   2.3 1.00e+00 2.94e-06f  9
#  567 -6.3269986e+03 2.36e-08 1.95e+02  -5.7 1.76e-01   1.8 1.30e-01 1.63e-06f 17
#  568 -6.3269988e+03 2.36e-08 1.96e+02  -5.7 6.50e-02   2.3 4.89e-01 1.99e-06f 18
#  569 -6.3269990e+03 2.36e-08 1.89e+02  -5.7 1.78e-01   1.8 1.34e-01 1.10e-06f 17
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  570 -6.3269990e+03 2.36e-08 1.95e+02  -5.7 1.11e-01   2.2 3.65e-01 3.01e-06f 16
#  571 -6.3269994e+03 2.36e-08 1.96e+02  -5.7 3.02e-02   2.6 6.08e-01 4.81e-06f 17
#  572 -6.3269996e+03 2.36e-08 1.96e+02  -5.7 9.36e-02   2.2 3.02e-01 1.98e-06f 17
#  573 -6.3269997e+03 2.36e-08 1.96e+02  -5.7 3.31e-02   2.6 9.26e-01 2.90e-06f  5
#  574 -6.1036962e+03 7.18e-06 1.94e+02  -5.7 9.71e-02   2.1 2.43e-01 3.14e-01w  1
#  575 -6.1037127e+03 7.18e-06 1.94e+02  -5.7 7.19e-02   2.5 2.83e-01 3.36e-05w  1
#  576 -6.2442611e+03 7.34e-06 8.41e+07  -5.7 1.63e-01   2.1 1.00e+00 1.12e-01w  1
#  577 -6.3269998e+03 2.36e-08 1.95e+02  -5.7 6.29e-02   2.5 2.43e-01 1.20e-06f 18
#  578 -6.3269998e+03 2.36e-08 1.96e+02  -5.7 1.19e-01   2.0 2.33e-01 1.29e-06f  6
#  579 -6.3269999e+03 2.36e-08 1.95e+02  -5.7 4.81e-02   2.4 8.89e-01 2.42e-06f 13
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  580 -6.3269999e+03 2.36e-08 1.96e+02  -5.7 1.18e-01   2.0 1.60e-01 1.00e-06f 19
#  581 -6.3270000e+03 2.36e-08 1.95e+02  -5.7 8.09e-02   2.4 8.54e-01 2.44e-06f 18
#  582 -6.3270001e+03 2.36e-08 1.96e+02  -5.7 2.76e-01   1.9 1.69e-01 8.87e-07f  9
#  583 -6.3270002e+03 2.36e-08 1.95e+02  -5.7 5.71e-02   2.3 8.71e-03 1.86e-06f 18
#  584 -6.3270003e+03 2.36e-08 1.96e+02  -5.7 1.88e-01   1.9 1.30e-01 4.46e-07f 20
#  585 -6.3270004e+03 2.36e-08 1.89e+02  -5.7 1.01e-01   2.3 5.68e-03 1.08e-06f 19
#  586 -6.3270005e+03 2.36e-08 1.89e+02  -5.7 1.86e-01   1.8 1.60e-01 4.04e-07f 21
#  587 -6.3266436e+03 2.35e-08 1.96e+02  -5.7 9.12e-02   2.2 1.00e+00 6.85e-04w  1
#  588 -6.2692527e+03 4.80e-07 8.43e+02  -5.7 3.43e-02   2.7 5.98e-02 2.60e-01w  1
#  589 -6.2560282e+03 2.42e-06 3.27e+06  -5.7 7.46e-02   2.2 8.37e-04 2.23e-01w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  590 -6.3270006e+03 2.36e-08 1.95e+02  -5.7 4.00e-02   2.6 1.00e+00 6.69e-07f 10
#  591 -6.3270006e+03 2.36e-08 1.96e+02  -5.7 9.10e-02   2.1 2.96e-01 4.78e-07f 18
#  592 -6.3270007e+03 2.36e-08 1.96e+02  -5.7 3.94e-02   2.6 2.27e-01 8.76e-07f 19
#  593 -6.3270007e+03 2.36e-08 1.89e+02  -5.7 1.29e-01   2.1 2.14e-01 2.36e-07f 12
#  594 -6.3270007e+03 2.36e-08 1.85e+02  -5.7 4.18e-02   2.5 9.26e-03 7.43e-07f 20
#  595 -6.3270008e+03 2.36e-08 1.96e+02  -5.7 1.15e-01   2.0 2.74e-01 1.30e-07f 23
#  596 -6.3270008e+03 2.36e-08 1.96e+02  -5.7 7.73e-02   2.5 1.48e-02 3.15e-07f 20
#  597 -6.3270008e+03 2.36e-08 1.95e+02  -5.7 1.21e-01   2.0 3.10e-01 1.13e-07f 21
#  598 -6.3270008e+03 2.36e-08 1.89e+02  -5.7 5.46e-02   2.4 4.42e-01 2.86e-07f 13
#  599 -6.3270008e+03 2.36e-08 1.96e+02  -5.7 1.51e-01   1.9 2.05e-01 9.06e-08f 23
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  600 -6.2787547e+03 4.75e-07 1.96e+02  -5.7 5.45e-02   2.4 3.47e-01 1.32e-01w  1
#  601 -6.2791897e+03 4.75e-07 1.96e+02  -5.7 3.51e-01   1.9 1.89e-04 2.22e-04w  1
#  602 -6.3080368e+03 5.05e-07 1.94e+02  -5.7 1.39e-01   2.3 2.84e-01 7.83e-02w  1
#  603 -6.2787547e+03 4.75e-07 1.96e+02  -5.7 1.81e-01   1.8 1.32e-01 1.32e-01s 19
#  604r-6.2787547e+03 4.75e-07 9.99e+02  -4.6 0.00e+00   2.3 0.00e+00 0.00e+00R  1
#  605r-6.2786934e+03 4.66e-07 1.68e+03  -4.6 1.19e+00    -  7.47e-01 9.90e-04f  1
#  606r-6.2674770e+03 5.77e-07 1.80e+02  -4.6 2.04e-01    -  9.90e-01 7.43e-01f  1
#  607r-6.2029686e+03 8.66e-05 9.98e+01  -4.6 3.11e-01    -  8.89e-01 1.00e+00f  1
#  608r-6.2124972e+03 3.98e-05 1.99e+02  -4.6 8.25e-02    -  8.06e-01 6.43e-01h  1
#  609r-6.2124787e+03 2.25e-05 2.19e+01  -4.6 2.19e-03   4.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  610r-6.2124646e+03 1.31e-06 1.54e-01  -4.6 4.63e-05   3.5 1.00e+00 1.00e+00h  1
#  611r-6.2124584e+03 2.27e-06 8.16e-02  -4.6 7.22e-05   3.0 1.00e+00 1.00e+00h  1
#  612r-6.2124494e+03 9.43e-08 3.43e-02  -4.6 9.55e-05   2.6 1.00e+00 1.00e+00h  1
#  613r-6.2124202e+03 7.67e-08 1.25e-02  -4.6 1.53e-04   2.1 1.00e+00 1.00e+00H  1
#  614r-6.2123577e+03 6.57e-08 5.24e-02  -4.6 4.15e-04   1.6 1.00e+00 1.00e+00h  1
#  615r-6.2122184e+03 5.20e-08 2.25e-02  -4.6 6.68e-04   1.1 1.00e+00 1.00e+00h  1
#  616r-6.2118854e+03 4.49e-08 3.67e-01  -4.6 1.96e-03   0.7 1.00e+00 1.00e+00H  1
#  617r-6.2119154e+03 4.49e-08 3.02e+00  -4.6 8.51e-02    -  1.03e-02 2.59e-03h  3
#  618r-6.2118990e+03 5.07e-08 3.10e-02  -4.6 8.66e-05   2.0 1.00e+00 1.00e+00h  1
#  619r-6.2118512e+03 4.51e-08 3.62e-02  -4.6 2.09e-04   1.5 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  620r-6.2117172e+03 4.49e-08 5.88e-03  -4.6 5.43e-04   1.0 1.00e+00 1.00e+00h  1
#  621r-6.2117357e+03 4.49e-08 1.31e-01  -4.6 5.42e-02    -  5.61e-03 1.40e-03h  3
#  622r-6.2117292e+03 4.50e-08 5.92e-03  -4.6 2.56e-05   2.4 1.00e+00 1.00e+00h  1
#  623r-6.2118669e+03 4.50e-08 3.43e-01  -4.6 4.86e-02    -  2.45e-02 1.22e-02f  2
#  624r-6.2118483e+03 4.49e-08 5.77e-03  -4.6 7.49e-05   1.9 1.00e+00 1.00e+00h  1
#  625r-6.2117939e+03 4.49e-08 5.51e-03  -4.6 2.14e-04   1.4 1.00e+00 1.00e+00h  1
#  626r-6.2116398e+03 4.49e-08 4.87e-03  -4.6 5.69e-04   0.9 1.00e+00 1.00e+00h  1
#  627r-6.2116413e+03 4.49e-08 1.35e-01  -4.6 1.49e-01    -  1.67e-03 1.05e-04h  5
#  628r-6.2116340e+03 4.49e-08 4.92e-03  -4.6 2.69e-05   2.3 1.00e+00 1.00e+00h  1
#  629r-6.2117557e+03 4.49e-08 5.23e-01  -4.6 8.80e-02    -  2.06e-02 1.03e-02f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  630r-6.2117343e+03 4.49e-08 4.79e-03  -4.6 7.87e-05   1.8 1.00e+00 1.00e+00h  1
#  631r-6.2118726e+03 4.49e-08 2.13e-01  -4.6 4.46e-02    -  2.73e-02 1.36e-02f  2
#  632r-6.2118645e+03 4.49e-08 4.81e-03  -4.6 2.89e-05   2.2 1.00e+00 1.00e+00h  1
#  633r-6.2120397e+03 4.49e-08 8.07e-01  -4.6 9.04e-02    -  3.09e-02 1.55e-02f  2
#  634r-6.2120165e+03 4.49e-08 4.56e-03  -4.6 8.43e-05   1.7 1.00e+00 1.00e+00h  1
#  635r-6.2121381e+03 4.49e-08 1.88e-01  -4.6 4.32e-02    -  2.48e-02 1.24e-02f  2
#  636r-6.2120601e+03 4.49e-08 1.19e-02  -4.6 5.39e-04   1.3 1.00e+00 1.00e+00h  1
#  637r-6.2123124e+03 4.49e-08 1.25e+00  -4.6 9.33e-02    -  4.64e-02 2.32e-02h  2
#  638r-6.2121239e+03 4.49e-08 3.80e-03  -4.6 6.32e-04   0.8 1.00e+00 1.00e+00h  1
#  639r-6.2122150e+03 4.49e-08 3.54e-01  -4.6 6.73e-02    -  1.82e-02 9.10e-03h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  640r-6.2121453e+03 4.49e-08 3.66e-03  -4.6 2.28e-04   1.2 1.00e+00 1.00e+00h  1
#  641r-6.2125085e+03 4.73e-08 1.93e+00  -4.6 9.42e-02    -  7.12e-02 3.56e-02h  2
#  642r-6.2123158e+03 4.49e-08 3.24e-03  -4.6 6.07e-04   0.7 1.00e+00 1.00e+00h  1
#  643r-6.2124097e+03 4.49e-08 5.63e-01  -4.6 1.02e-01    -  1.91e-02 9.55e-03h  2
#  644r-6.2118777e+03 4.49e-08 3.36e-03  -4.6 1.46e-03   0.3 1.00e+00 1.00e+00h  1
#  645r-6.2129227e+03 4.47e-07 2.68e-03  -4.6 9.12e-02    -  1.14e-01 1.14e-01h  1
#  646r-6.2182163e+03 1.81e-05 2.41e-01  -4.6 8.04e-02    -  8.35e-01 8.37e-01h  1
#  647r-6.2174759e+03 4.88e-08 1.21e-03  -4.6 2.03e-03  -0.2 1.00e+00 1.00e+00h  1
#  648r-6.2238040e+03 3.75e-07 1.56e-01  -6.9 2.30e-01    -  1.69e-01 1.69e-01f  1
#  649r-6.2280137e+03 6.27e-07 2.72e-01  -6.9 2.75e-02    -  3.50e-01 3.50e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  650r-6.2366751e+03 4.30e-06 1.97e+01  -6.9 4.17e-02    -  8.29e-01 7.78e-01f  1
#  651r-6.2366756e+03 1.45e-06 1.72e+02  -6.9 2.09e-04   1.1 9.03e-01 6.62e-01f  1
#  652r-6.2366759e+03 3.40e-07 7.16e+01  -6.9 7.08e-05   1.5 9.57e-01 7.66e-01f  1
#  653r-6.2366775e+03 2.37e-10 2.59e-04  -6.9 1.66e-05   1.1 1.00e+00 1.00e+00f  1
#  654r-6.2366835e+03 2.28e-10 3.53e-04  -6.9 2.92e-06   0.6 1.00e+00 1.00e+00h  1
#  655r-6.2367013e+03 2.28e-10 9.86e-05  -6.9 8.80e-06   0.1 1.00e+00 1.00e+00h  1
#  656r-6.2367547e+03 2.28e-10 1.10e-05  -6.9 2.64e-05  -0.4 1.00e+00 1.00e+00h  1
#  657r-6.2369147e+03 2.28e-10 4.50e-05  -6.9 7.87e-05  -0.9 1.00e+00 1.00e+00h  1
#  658r-6.2373914e+03 2.28e-10 3.93e-04  -6.9 2.33e-04  -1.3 1.00e+00 1.00e+00h  1
#  659r-6.2387932e+03 1.02e-09 3.24e-03  -6.9 6.71e-04  -1.8 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  660r-6.2426806e+03 8.04e-09 2.28e-02  -6.9 1.80e-03  -2.3 1.00e+00 1.00e+00h  1
#  661r-6.2434070e+03 7.72e-09 2.09e+00  -6.9 4.02e-03  -2.8 1.54e-01 7.70e-02h  2
#  662r-6.2434074e+03 3.89e-10 2.07e-03  -6.9 9.79e-06   2.2 1.00e+00 1.00e+00h  1
#  663r-6.2434080e+03 2.35e-10 1.58e-03  -6.9 1.06e-05   1.7 1.00e+00 1.00e+00h  1
#  664r-6.2434091e+03 2.29e-10 2.32e-05  -6.9 5.45e-07   1.2 1.00e+00 1.00e+00h  1
#  665r-6.2434123e+03 2.29e-10 9.09e-06  -6.9 1.64e-06   0.7 1.00e+00 1.00e+00h  1
#  666r-6.2434219e+03 2.28e-10 9.09e-06  -6.9 4.91e-06   0.3 1.00e+00 1.00e+00h  1
#  667r-6.2434506e+03 2.28e-10 9.08e-06  -6.9 1.47e-05  -0.2 1.00e+00 1.00e+00h  1
#  668r-6.2435364e+03 2.28e-10 1.30e-05  -6.9 4.40e-05  -0.7 1.00e+00 1.00e+00h  1
#  669r-6.2435643e+03 2.28e-10 2.87e-01  -6.9 1.31e-04  -1.2 4.35e-01 1.09e-01h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  670r-6.2435645e+03 2.30e-10 2.07e-04  -6.9 2.09e-06   2.0 1.00e+00 1.00e+00h  1
#  671r-6.2435650e+03 2.29e-10 9.05e-06  -6.9 2.90e-07   1.5 1.00e+00 1.00e+00h  1
#  672r-6.2435667e+03 2.29e-10 9.04e-06  -6.9 8.69e-07   1.0 1.00e+00 1.00e+00h  1
#  673r-6.2435718e+03 2.29e-10 9.04e-06  -6.9 2.61e-06   0.5 1.00e+00 1.00e+00h  1
#  674r-6.2435870e+03 2.28e-10 9.04e-06  -6.9 7.82e-06   0.1 1.00e+00 1.00e+00h  1
#  675r-6.2436325e+03 2.28e-10 9.02e-06  -6.9 2.34e-05  -0.4 1.00e+00 1.00e+00h  1
#  676r-6.2437637e+03 2.27e-10 1.46e-03  -6.9 6.99e-05  -0.9 1.00e+00 1.00e+00H  1
#  677r-6.2437645e+03 2.40e-10 6.41e-04  -6.9 4.67e-06   1.3 1.00e+00 1.00e+00h  1
#  678r-6.2437667e+03 2.29e-10 1.32e-05  -6.9 1.23e-06   0.9 1.00e+00 1.00e+00h  1
#  679r-6.2437734e+03 2.28e-10 8.98e-06  -6.9 3.69e-06   0.4 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  680r-6.2437935e+03 2.28e-10 8.97e-06  -6.9 1.11e-05  -0.1 1.00e+00 1.00e+00h  1
#  681r-6.2438537e+03 2.28e-10 8.95e-06  -6.9 3.31e-05  -0.6 1.00e+00 1.00e+00h  1
#  682r-6.2440338e+03 2.27e-10 1.91e-03  -6.9 9.86e-05  -1.0 1.00e+00 1.00e+00H  1
#  683r-6.2440422e+03 2.29e-10 2.63e-04  -6.9 4.62e-06   0.3 1.00e+00 1.00e+00h  1
#  684r-6.2440676e+03 2.28e-10 4.63e-05  -6.9 1.38e-05  -0.2 1.00e+00 1.00e+00h  1
#  685r-6.2441434e+03 2.27e-10 1.15e-05  -6.9 4.14e-05  -0.7 1.00e+00 1.00e+00h  1
#  686r-6.2441585e+03 2.27e-10 1.64e-01  -6.9 1.23e-04  -1.1 2.66e-01 6.64e-02h  3
#  687r-6.2441587e+03 2.28e-10 1.57e-04  -6.9 1.61e-06   2.0 1.00e+00 1.00e+00h  1
#  688r-6.2451158e+03 1.73e-09 2.12e-02  -6.9 2.96e-01    -  3.83e-02 3.84e-02f  1
#  689r-6.2468045e+03 1.09e-08 2.34e-01  -6.9 2.83e-01    -  7.71e-02 7.78e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  690r-6.2519490e+03 9.24e-08 3.00e+00  -6.9 2.59e-01    -  2.98e-01 3.09e-01f  1
#  691r-6.2619329e+03 3.62e-07 6.48e+00  -6.9 1.71e-01    -  8.89e-01 9.41e-01f  1
#  692r-6.2619226e+03 2.28e-10 1.10e-02  -6.9 3.40e-04   1.5 1.00e+00 1.00e+00f  1
#  693r-6.2619226e+03 2.29e-10 2.06e-06  -6.9 1.92e-07   1.0 1.00e+00 1.00e+00h  1
#  694r-6.2619240e+03 7.90e-11 3.98e+01  -9.0 7.43e-06   0.6 1.00e+00 7.83e-01f  1
#  695r-6.2619240e+03 2.99e-11 5.92e+01  -9.0 3.75e-06   1.9 9.11e-01 6.98e-01f  1
#  696r-6.261
# Dict{String, Any} with 8 entries:
#   "solve_time"         => 120.437
#   "optimizer"          => "Ipopt"
#   "termination_status" => OTHER_ERROR
#   "dual_status"        => UNKNOWN_RESULT_STATUS
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => -6276.95
#   "solution"           => Dict{String, Any}("nw"=>Dict{String, Dict{String, Any…
#   "objective_lb"       => -Inf

# %%
########################
# avaliando resultados #
########################
line2_active_power = []
line3_active_power = []

load1_active_power = []
load2_active_power = []

pv1_active_power = []
pv2_active_power = []

bess_1_active_power = []
bess_2_active_power = []
bess_1_state = []
bess_2_state = []

bus_n3_1_voltage = []
bus_n3_2_voltage = []
bus_n3_3_voltage = []

for i in 1:96
    # line
    push!(line2_active_power, sum(result["solution"]["nw"]["$i"]["line"]["line2"]["pt"]))
    push!(line3_active_power, sum(result["solution"]["nw"]["$i"]["line"]["line3"]["pt"]))

    # load
    push!(load1_active_power, sum(result["solution"]["nw"]["$i"]["load"]["load1"]["pd"]))
    push!(load2_active_power, sum(result["solution"]["nw"]["$i"]["load"]["load2"]["pd"]))

    # solar
    push!(pv1_active_power, .- sum(result["solution"]["nw"]["$i"]["solar"]["pv1"]["pg"]))
    push!(pv2_active_power, .- sum(result["solution"]["nw"]["$i"]["solar"]["pv2"]["pg"]))

    # bess
    push!(bess_1_active_power, sum(result["solution"]["nw"]["$i"]["storage"]["bess_1"]["ps"]))
    push!(bess_1_state, result["solution"]["nw"]["$i"]["storage"]["bess_1"]["se"])
    push!(bess_2_active_power, sum(result["solution"]["nw"]["$i"]["storage"]["bess_2"]["ps"]))
    push!(bess_2_state, result["solution"]["nw"]["$i"]["storage"]["bess_2"]["se"])

    # bus
    push!(bus_n3_1_voltage, result["solution"]["nw"]["$i"]["bus"]["n4"]["vm"][1])
    push!(bus_n3_2_voltage, result["solution"]["nw"]["$i"]["bus"]["n4"]["vm"][2])
    push!(bus_n3_3_voltage, result["solution"]["nw"]["$i"]["bus"]["n4"]["vm"][3])

end

#######################################
# plotagem de graficos para validacao #
#######################################
time = time_indexes ./ 4
bar(time, load1_active_power + load2_active_power, label="Carga 1", linewidth=0.5)
bar!(time, pv1_active_power + pv2_active_power, label="Sistema FV", linewidth=0.5)
bar!(time, bess_1_active_power + bess_2_active_power, label="Armazenamento", linewidth=0.5)
bar!(time, line2_active_power + line3_active_power, label="Fluxo na Linha", linewidth=0.5)
title!("Potência Ativa dos Componentes")
xlabel!("Tempo (h)")
ylabel!("Potência (W)")
savefig(results_path * "potencia_ativa high.png")

bar(time, pv1_active_power .+ pv2_active_power .+
          bess_1_active_power .+ bess_2_active_power .+
          load1_active_power .+ load2_active_power,
          label="Balanço no barramento", linewidth=0.5)
bar!(time, line2_active_power .+ line3_active_power, label="Fluxo na Linha", linewidth=0.5)
title!("Comparacao balanço e fluxo na linha")
xlabel!("Tempo (h)")
ylabel!("Potência (W)")
savefig(results_path * "validacao_linha high.png")


plot(time, bess_1_active_power, 
    label="Potência Ativa (W)", 
    ylabel="Potência Ativa (W)",
    legend=:topright)
plot!(twinx(), time, bess_1_state, 
    label="Estado do Armazenamento (Wh)", 
    color=:red,
    ylabel="Estado de Carga (Wh)",
    legend=:topleft)
title!("Potência Ativa e Estado do Armazenamento")
savefig(results_path * "estado_armazenamento_ativo_1 high.png")
    

plot(time, bess_2_active_power, 
    label="Potência Ativa (W)", 
    ylabel="Potência Ativa (W)",
    legend=:topright)
plot!(twinx(), time, bess_2_state, 
    label="Estado do Armazenamento (Wh)", 
    color=:red,
    ylabel="Estado de Carga (Wh)",
    legend=:topleft)
title!("Potência Ativa e Estado do Armazenamento")
savefig(results_path * "estado_armazenamento_ativo_2 high.png")


plot(time, bus_n3_1_voltage, label="Tensão na Fase 1", linewidth=2)
plot!(time, bus_n3_2_voltage, label="Tensão na Fase 2", linewidth=2)
plot!(time, bus_n3_3_voltage, label="Tensão na Fase 3", linewidth=2)
title!("Tensão nas fases (barramento n3)")
xlabel!("Tempo (h)")
ylabel!("Tensão em Kv")
savefig(results_path * "tensao_barramento high.png")
    
plot(time, gen_data.pgen .* (1500), linewidth=2)
bar!(time, .- pv1_active_power, linewidth=2)
bar!(time, .- pv2_active_power, linewidth=2)
title!("Geração nominal solar")
xlabel!("Tempo (h)")
ylabel!("Tensão em Kv")
savefig(results_path * "geracao em PU high.png")
# Out:
# "/home/luizfreire/Documents/mestrado/powerModelsExemplos/results/2025-04-21_solar_carga_armazenamento_opf_cost/geracao em PU high.png"

# %%
source = []
for i in 1:96
    push!(source, sum(result["solution"]["nw"]["$i"]["voltage_source"]["source"]["pg"]))
end

# %%
sum(+ 50 * (pv1_active_power + pv2_active_power)
    + 50 * max.(0, bess_1_active_power + bess_2_active_power)
    + 30 * min.(0, bess_1_active_power + bess_2_active_power)
    + 100 * max.(0, source)
    - 100 * min.(0, source))/ 1000
# Out:
# -6277.145472718572

# %%
sum(source)
# Out:
# 1965.0404332516466

# %%
eng_model["nw"]["1"]["settings"]["power_scale_factor"]
# Out:
# 1000.0

# %%
transform_data_model(eng_model)["nw"]["50"]["gen"]["3"]
# Out:
# Dict{String, Any} with 21 entries:
#   "pg"            => [0.0, 0.0, 0.0]
#   "model"         => 2
#   "connections"   => [1, 2, 3]
#   "shutdown"      => 0.0
#   "startup"       => 0.0
#   "configuration" => WYE
#   "name"          => "_virtual_gen.voltage_source.source"
#   "qg"            => [0.0, 0.0, 0.0]
#   "gen_bus"       => 10
#   "pmax"          => [Inf, Inf, Inf]
#   "vbase"         => 7.19956
#   "source_id"     => "voltage_source.source"
#   "vg"            => [0.001, 0.001, 0.001]
#   "index"         => 3
#   "cost"          => [-100, 100]
#   "gen_status"    => 1
#   "qmax"          => [Inf, Inf, Inf]
#   "qmin"          => [-Inf, -Inf, -Inf]
#   "control_mode"  => 1
#   "pmin"          => [-Inf, -Inf, -Inf]
#   "ncost"         => 2
